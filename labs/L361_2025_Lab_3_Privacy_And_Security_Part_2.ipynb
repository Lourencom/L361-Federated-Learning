# %% [markdown]
# # 0. Marking.
#
# **_IMPORTANT_**: Save a copy of this notebook into your Drive before you start.
#
# - Please attempt all the questions marked for your group (Part II ✅ | Part III/MPhil ✅).
#
# Please submit a zip file, containing both parts, consiting of of:
#
# 1. A text file with a publicly visible link to your notebooks in Google Colab or GitHub.
# 2. A downloaded copy (ipynb) of your notebooks or your zipped cloned GitHub repo. You may treat these as a report: we will not be re-executing the code you used to produce the answers unless required.
#
# If you find yourself enjoying the material, feel free to attempt more! Provide your answers in a new cell below the question cell.

# %% [markdown]
# ## Imports

# %%
# The simulation component of flower uses RAY under the hood.
# `pip` could produce some errors. Nothing to worry about.
# The execution has been verified; it is working anyway.
! pip install --quiet --upgrade "pip"
! pip install --quiet \
    git+https://github.com/Iacob-Alexandru-Andrei/flower.git@teaching ray=="2.6.3" \
    torch=="2.2.1" torchvision=="0.17.1"  tqdm=="4.67.1" torchsummary=="1.5.1" \
    pycrypto cryptography=="41.0.2" pycryptodome=="3.18.0" matplotlib=="3.8.2"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 18.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 MB 60.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.6/755.6 MB 39.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 22.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 57.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 53.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 64.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 43.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 124.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 144.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 30.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 42.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 65.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 64.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 69.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 50.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 60.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 MB 59.2 MB/s eta 0:00:00
#   Building wheel for flwr (pyproject.toml) ... done
#   Building wheel for pycrypto (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-status 1.62.3 requires protobuf>=4.21.6, but you have protobuf 3.20.3 which is incompatible.
# pyopenssl 24.2.1 requires cryptography<44,>=41.0.5, but you have cryptography 41.0.2 which is incompatible.
# torchaudio 2.5.1+cu124 requires torch==2.5.1, but you have torch 2.2.1 which is incompatible.
# tensorflow-metadata 1.16.1 requires protobuf<6.0.0dev,>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.3 which is incompatible.

# %%
# Imports
import os
import random
from collections.abc import Callable
from typing import Any
from pathlib import Path

import flwr as fl
import numpy as np

import torch
from flwr.client import Client
from flwr.common.typing import NDArrays
from flwr.server import ServerConfig, History
from flwr.server.strategy import Strategy
from enum import IntEnum
from datetime import datetime, timezone
import json

import matplotlib.pyplot as plt

# Add new seeds here for easy autocomplete
class Seeds(IntEnum):
    """Seeds for reproducibility."""

    DEFAULT = 1337


np.random.seed(Seeds.DEFAULT)
random.seed(Seeds.DEFAULT)
torch.manual_seed(Seeds.DEFAULT)
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True

PathType = Path | str | None

# %% [markdown]
# ### Paths

# %%
home_dir = Path.cwd()
data_dir: Path = home_dir / "data"

# %% [markdown]
# ### Useful Python functions

# %%
def convert(o: Any) -> int | float:
    """Convert input object to Python numerical if numpy."""
    # type: ignore[reportGeneralTypeIssues]
    if isinstance(o, np.int32 | np.int64):
        return int(o)
    # type: ignore[reportGeneralTypeIssues]
    if isinstance(o, np.float32 | np.float64):
        return float(o)
    raise TypeError


def save_history(hist: History, name: str) -> None:
    """Save history from simulation to file."""
    time = int(datetime.now(timezone.utc).timestamp())
    path = home_dir / "histories"
    path.mkdir(exist_ok=True)
    path = path / f"hist_{time}_{name}.json"
    with open(path, "w", encoding="utf-8") as f:
        json.dump(hist.__dict__, f, ensure_ascii=False, indent=4, default=convert)


def start_seeded_simulation(
    client_fn: Callable[[str], Client],
    num_clients: int,
    config: ServerConfig,
    strategy: Strategy,
    name: str,
    seed: int = Seeds.DEFAULT,
    iteration: int = 0,
) -> tuple[list[tuple[int, NDArrays]], History]:
    """Wrap simulation to always seed client selection."""
    np.random.seed(seed ^ iteration)
    torch.manual_seed(seed ^ iteration)
    random.seed(seed ^ iteration)
    parameter_list, hist = fl.simulation.start_simulation_no_ray(
        client_fn=client_fn,
        num_clients=num_clients,
        client_resources={},
        config=config,
        strategy=strategy,
    )
    save_history(hist, name)
    return parameter_list, hist

# %% [markdown]
# ### Dataset

# %%
from common.client import get_flower_client_generator
from common.client_utils import (
    get_network_generator_cnn,
    get_model_parameters,
)

# %%
np.random.seed(Seeds.DEFAULT)
random.seed(Seeds.DEFAULT)
torch.manual_seed(Seeds.DEFAULT)
network_generator_cnn = get_network_generator_cnn()
seed_net_cnn = network_generator_cnn()
seed_model_cnn_params: NDArrays = get_model_parameters(seed_net_cnn)
federated_evaluation_function = None

# %%
fl_client_gen = get_flower_client_generator(network_generator_cnn, home_dir, home_dir)

# %% [markdown]
# # Secure Aggregation

# %% [markdown]
# In this section, we will explore a **Secure Multi-Party Computation (SMPC)** based approach first implemented in an FL context in [this](https://arxiv.org/abs/1611.04482) paper, called **Secure Aggregation**.
# The authors proposed a protocol for the secure aggregation of model updates in a Federated Learning setting.
# SMPC algorithms allow a group of _mutually distrustful parties_ to compute a function over their private inputs without revealing any information about their inputs to one another.
# In Federated Learning, users can compute the average of their model updates without revealing any information about their model updates to the other actors.
# This is achieved by a complex exchange of encrypted keys and messages between the actors, which is why the protocol is _computationally expensive_.
# The additional information the server and clients exchanges results in additional _communication overhead_.
# In this Lab, we will focus on the communication overhead, ignoring the computational overhead. Furthermore, the protocol requires a specific fraction of clients to complete training to compute the average.
#
# [Pan Heng](https://github.com/panh99) implemented the first Secure Aggregation in Flower. Thus, we will use part of his code in this section. However, because of the complexity of this protocol, we refer all the discussions to the original paper.
# The main takeaways from the paper are the following: private inputs of clients are completely protected in this setting; Secure Aggregation is computationally expensive and requires a lot of communication overhead; the scalability of Secure Aggregation to many clients requires a lot of computational resources.
#
# In the following cell, we will download the code for the Secure Aggregation protocol.

# %%
secagg_dir = home_dir / "secagg"

# %% [markdown]
# The implementation contains many encryption utilities, and thus it is very complex.
# So, feel free to dig into the code, but be aware that it is unnecessary to understand every part of it to complete the Lab.
#
# We also need to create a folder to store the keys generated on the fly by our simulation.

# %%
keys_dir = secagg_dir / "client_data"
keys_dir.mkdir(exist_ok=True, parents=True)

# %% [markdown]
# We are now importing the relevant functions for simulating the Secure Aggregation protocol from the files we have just downloaded.

# %%
from common.secagg.client import get_sec_agg_client_generator as get_client_generator
from common.secagg.strategy import SecureAggregationStrategy

# %% [markdown]
# It is important to point out that from now on we will use a toy simulator.
# This means that we will not use real clients, so we are not training anything.
# We will just simulate the communication between the server and the clients to explore the communication overhead.
# The scripts are built to return to the `aggregate_fit` function of the server the length of the bytes exchanged during all the phases of communication of the Secure Aggregation protocol.
# The equivalent single FL training round is achieved in 4 phases of communication by the protocol.
#
# It is worth mentioning that for this implementation we will change our training round from using epochs to local steps because we need all the clients to train on the same amount of data samples.
# This is done because even the number of samples could be considered sensitive information that we do not want to reveal to the other actors.

# %%
num_total_clients = 3290

# %%
def run_sec_agg_demo(
    num_clients_per_round: int = 10,
    n_model_parameters: int = 10000,
    min_num_surviving_clients: int = 5,
    n_rounds: int = 2,
    n_samples: int = 30,
) -> Any:
    """Execute a secure aggregation simulation."""
    strategy = SecureAggregationStrategy(
        n_dim=n_model_parameters,
        num_clients_per_round=num_clients_per_round,
        threshold=min_num_surviving_clients,
        num_dropouts=num_clients_per_round - min_num_surviving_clients,
    )
    secagg_hist = start_seeded_simulation(
        client_fn=lambda cid: get_client_generator(
            n_model_parameters, n_samples, keys_dir
        )(cid).to_client(),
        num_clients=num_total_clients,
        # this refers to the number of phases to simulate (must be 4*n_rounds)
        config=ServerConfig(num_rounds=int(4 * n_rounds)),
        strategy=strategy,
        name=f"secagg_{num_clients_per_round}_{n_model_parameters}_{min_num_surviving_clients}_{n_rounds}_{n_samples}",
    )
    # Clean up keys from the folder
    for filename in os.listdir(keys_dir):
        file_pth = keys_dir / filename
        if filename.endswith(".pth"):
            Path.unlink(file_pth)

    return secagg_hist

# %% [markdown]
# In the next cell, we will simulate the Secure Aggregation protocol defined by the abovementioned parameters.

# %%
parameters_for_every_round, secagg_hist = run_sec_agg_demo()
# Out:
# INFO flwr 2025-02-21 18:03:13,941 | app.py:149 | Starting Flower simulation, config: ServerConfig(num_rounds=8, round_timeout=None)
# INFO:flwr:Starting Flower simulation, config: ServerConfig(num_rounds=8, round_timeout=None)
# INFO flwr 2025-02-21 18:03:13,955 | server_returns_parameters.py:81 | Initializing global parameters
# INFO:flwr:Initializing global parameters
# INFO flwr 2025-02-21 18:03:13,956 | server_returns_parameters.py:273 | Using initial parameters provided by strategy
# INFO:flwr:Using initial parameters provided by strategy
# INFO flwr 2025-02-21 18:03:13,958 | server_returns_parameters.py:84 | Evaluating initial parameters
# INFO:flwr:Evaluating initial parameters
# INFO flwr 2025-02-21 18:03:13,959 | server_returns_parameters.py:97 | FL starting
# INFO:flwr:FL starting
# INFO flwr 2025-02-21 18:03:13,962 | strategy.py:120 | Configure fit: stage 0, 0, True
# INFO:flwr:Configure fit: stage 0, 0, True
# INFO flwr 2025-02-21 18:03:13,963 | strategy.py:126 | Stage 0
# INFO:flwr:Stage 0
# DEBUG flwr 2025-02-21 18:03:13,966 | server_returns_parameters.py:223 | fit_round 1: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 1: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-21 18:03:13,968 | client.py:181 | Client 0: starting stage 0...
# INFO:flwr:Client 0: starting stage 0...
# INFO flwr 2025-02-21 18:03:13,975 | client.py:181 | Client 1: starting stage 0...
# INFO:flwr:Client 1: starting stage 0...
# INFO flwr 2025-02-21 18:03:13,975 | client.py:181 | Client 2: starting stage 0...
# INFO:flwr:Client 2: starting stage 0...
# INFO flwr 2025-02-21 18:03:13,978 | client.py:181 | Client 3: starting stage 0...
# INFO:flwr:Client 3: starting stage 0...
# INFO flwr 2025-02-21 18:03:13,983 | client.py:181 | Client 4: starting stage 0...
# INFO:flwr:Client 4: starting stage 0...
# INFO flwr 2025-02-21 18:03:13,986 | client.py:181 | Client 5: starting stage 0...
# INFO:flwr:Client 5: starting stage 0...
# INFO flwr 2025-02-21 18:03:14,010 | client.py:209 | Client 1: stage 0 completes. uploading public keys...
# INFO:flwr:Client 1: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:03:14,014 | client.py:209 | Client 2: stage 0 completes. uploading public keys...
# INFO:flwr:Client 2: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:03:14,026 | client.py:209 | Client 3: stage 0 completes. uploading public keys...
# INFO:flwr:Client 3: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:03:14,028 | client.py:181 | Client 6: starting stage 0...
# INFO:flwr:Client 6: starting stage 0...
# INFO flwr 2025-02-21 18:03:14,030 | client.py:181 | Client 7: starting stage 0...
# INFO:flwr:Client 7: starting stage 0...
# INFO flwr 2025-02-21 18:03:14,032 | client.py:209 | Client 4: stage 0 completes. uploading public keys...
# INFO:flwr:Client 4: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:03:14,045 | client.py:209 | Client 0: stage 0 completes. uploading public keys...
# INFO:flwr:Client 0: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:03:14,047 | client.py:181 | Client 8: starting stage 0...
# INFO:flwr:Client 8: starting stage 0...
# INFO flwr 2025-02-21 18:03:14,053 | client.py:181 | Client 9: starting stage 0...
# INFO:flwr:Client 9: starting stage 0...
# INFO flwr 2025-02-21 18:03:14,070 | client.py:209 | Client 7: stage 0 completes. uploading public keys...
# INFO:flwr:Client 7: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:03:14,061 | client.py:209 | Client 5: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:03:14,057 | client.py:209 | Client 6: stage 0 completes. uploading public keys...
# INFO:flwr:Client 5: stage 0 completes. uploading public keys...
# INFO:flwr:Client 6: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:03:14,079 | client.py:209 | Client 9: stage 0 completes. uploading public keys...
# INFO:flwr:Client 9: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:03:14,089 | client.py:209 | Client 8: stage 0 completes. uploading public keys...
# INFO:flwr:Client 8: stage 0 completes. uploading public keys...
# DEBUG flwr 2025-02-21 18:03:14,103 | server_returns_parameters.py:237 | fit_round 1 received 10 results and 0 failures
# DEBUG:flwr:fit_round 1 received 10 results and 0 failures
# INFO flwr 2025-02-21 18:03:14,104 | strategy.py:186 | Length of content is 450
# INFO:flwr:Length of content is 450
# INFO flwr 2025-02-21 18:03:14,106 | server_returns_parameters.py:171 | evaluate_round 1: no clients selected, cancel
# INFO:flwr:evaluate_round 1: no clients selected, cancel
# INFO flwr 2025-02-21 18:03:14,106 | strategy.py:120 | Configure fit: stage 1, 0, False
# INFO:flwr:Configure fit: stage 1, 0, False
# DEBUG flwr 2025-02-21 18:03:14,107 | server_returns_parameters.py:223 | fit_round 2: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 2: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-21 18:03:14,109 | client.py:146 | CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO:flwr:CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO flwr 2025-02-21 18:03:14,118 | client.py:146 | CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO:flwr:CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO flwr 2025-02-21 18:03:14,120 | client.py:221 | Client 1: starting stage 1...
# INFO:flwr:Client 1: starting stage 1...
# INFO flwr 2025-02-21 18:03:14,121 | client.py:221 | Client 8: starting stage 1...
# INFO:flwr:Client 8: starting stage 1...
# INFO flwr 2025-02-21 18:03:14,123 | client.py:146 | CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO flwr 2025-02-21 18:03:14,124 | client.py:146 | CID 678 reloading from /content/secagg/client_data/678.pth
# INFO:flwr:CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO flwr 2025-02-21 18:03:14,131 | client.py:146 | CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO:flwr:CID 678 reloading from /content/secagg/client_data/678.pth
# INFO flwr 2025-02-21 18:03:14,134 | client.py:146 | CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO flwr 2025-02-21 18:03:14,135 | client.py:221 | Client 3: starting stage 1...
# INFO:flwr:CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO flwr 2025-02-21 18:03:14,139 | client.py:221 | Client 7: starting stage 1...
# INFO:flwr:CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO flwr 2025-02-21 18:03:14,146 | client.py:221 | Client 5: starting stage 1...
# INFO:flwr:Client 3: starting stage 1...
# INFO:flwr:Client 7: starting stage 1...
# INFO:flwr:Client 5: starting stage 1...
# INFO flwr 2025-02-21 18:03:14,148 | client.py:221 | Client 9: starting stage 1...
# INFO:flwr:Client 9: starting stage 1...
# INFO flwr 2025-02-21 18:03:14,205 | client.py:287 | Client 8: stage 1 completes. uploading key shares...
# INFO:flwr:Client 8: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:03:14,209 | client.py:146 | CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO:flwr:CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO flwr 2025-02-21 18:03:14,220 | client.py:221 | Client 6: starting stage 1...
# INFO:flwr:Client 6: starting stage 1...
# INFO flwr 2025-02-21 18:03:14,329 | client.py:287 | Client 9: stage 1 completes. uploading key shares...
# INFO:flwr:Client 9: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:03:14,337 | client.py:146 | CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO:flwr:CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO flwr 2025-02-21 18:03:14,363 | client.py:221 | Client 4: starting stage 1...
# INFO:flwr:Client 4: starting stage 1...
# INFO flwr 2025-02-21 18:03:14,392 | client.py:287 | Client 7: stage 1 completes. uploading key shares...
# INFO:flwr:Client 7: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:03:14,395 | client.py:287 | Client 3: stage 1 completes. uploading key shares...
# INFO:flwr:Client 3: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:03:14,412 | client.py:146 | CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO:flwr:CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO flwr 2025-02-21 18:03:14,401 | client.py:287 | Client 5: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:03:14,415 | client.py:146 | CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO:flwr:Client 5: stage 1 completes. uploading key shares...
# INFO:flwr:CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO flwr 2025-02-21 18:03:14,424 | client.py:221 | Client 2: starting stage 1...
# INFO:flwr:Client 2: starting stage 1...
# INFO flwr 2025-02-21 18:03:14,425 | client.py:221 | Client 0: starting stage 1...
# INFO:flwr:Client 0: starting stage 1...
# INFO flwr 2025-02-21 18:03:14,432 | client.py:287 | Client 1: stage 1 completes. uploading key shares...
# INFO:flwr:Client 1: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:03:14,474 | client.py:287 | Client 6: stage 1 completes. uploading key shares...
# INFO:flwr:Client 6: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:03:14,537 | client.py:287 | Client 4: stage 1 completes. uploading key shares...
# INFO:flwr:Client 4: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:03:14,564 | client.py:287 | Client 0: stage 1 completes. uploading key shares...
# INFO:flwr:Client 0: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:03:14,583 | client.py:287 | Client 2: stage 1 completes. uploading key shares...
# INFO:flwr:Client 2: stage 1 completes. uploading key shares...
# DEBUG flwr 2025-02-21 18:03:14,592 | server_returns_parameters.py:237 | fit_round 2 received 10 results and 0 failures
# DEBUG:flwr:fit_round 2 received 10 results and 0 failures
# INFO flwr 2025-02-21 18:03:14,594 | strategy.py:186 | Length of content is 7916
# INFO:flwr:Length of content is 7916
# INFO flwr 2025-02-21 18:03:14,597 | server_returns_parameters.py:171 | evaluate_round 2: no clients selected, cancel
# INFO:flwr:evaluate_round 2: no clients selected, cancel
# INFO flwr 2025-02-21 18:03:14,598 | strategy.py:120 | Configure fit: stage 2, 0, False
# INFO:flwr:Configure fit: stage 2, 0, False
# DEBUG flwr 2025-02-21 18:03:14,600 | server_returns_parameters.py:223 | fit_round 3: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 3: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-21 18:03:14,606 | client.py:146 | CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO:flwr:CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO flwr 2025-02-21 18:03:14,612 | client.py:295 | Client 6: starting stage 2...
# INFO:flwr:Client 6: starting stage 2...
# INFO flwr 2025-02-21 18:03:14,615 | client.py:146 | CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO:flwr:CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO flwr 2025-02-21 18:03:14,621 | client.py:146 | CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO:flwr:CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO flwr 2025-02-21 18:03:14,628 | client.py:295 | Client 0: starting stage 2...
# INFO:flwr:Client 0: starting stage 2...
# INFO flwr 2025-02-21 18:03:14,629 | client.py:146 | CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO:flwr:CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO flwr 2025-02-21 18:03:14,630 | client.py:295 | Client 1: starting stage 2...
# INFO:flwr:Client 1: starting stage 2...
# INFO flwr 2025-02-21 18:03:14,638 | client.py:146 | CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO:flwr:CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO flwr 2025-02-21 18:03:14,649 | client.py:295 | Client 9: starting stage 2...
# INFO:flwr:Client 9: starting stage 2...
# INFO flwr 2025-02-21 18:03:14,643 | client.py:295 | Client 2: starting stage 2...
# INFO:flwr:Client 2: starting stage 2...
# INFO flwr 2025-02-21 18:03:14,644 | client.py:146 | CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO:flwr:CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO flwr 2025-02-21 18:03:14,645 | client.py:146 | CID 678 reloading from /content/secagg/client_data/678.pth
# INFO:flwr:CID 678 reloading from /content/secagg/client_data/678.pth
# INFO flwr 2025-02-21 18:03:14,641 | client.py:146 | CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO:flwr:CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO flwr 2025-02-21 18:03:14,669 | client.py:295 | Client 7: starting stage 2...
# INFO:flwr:Client 7: starting stage 2...
# INFO flwr 2025-02-21 18:03:14,671 | client.py:146 | CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO:flwr:CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO flwr 2025-02-21 18:03:14,671 | client.py:295 | Client 3: starting stage 2...
# INFO:flwr:Client 3: starting stage 2...
# INFO flwr 2025-02-21 18:03:14,674 | client.py:295 | Client 4: starting stage 2...
# INFO:flwr:Client 4: starting stage 2...
# INFO flwr 2025-02-21 18:03:14,681 | client.py:295 | Client 5: starting stage 2...
# INFO:flwr:Client 5: starting stage 2...
# INFO flwr 2025-02-21 18:03:14,692 | client.py:146 | CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO:flwr:CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO flwr 2025-02-21 18:03:14,710 | client.py:295 | Client 8: starting stage 2...
# INFO:flwr:Client 8: starting stage 2...
# INFO flwr 2025-02-21 18:03:14,722 | client.py:397 | Client 6: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 6: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:03:14,753 | client.py:397 | Client 9: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 9: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:03:14,764 | client.py:397 | Client 7: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 7: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:03:14,797 | client.py:397 | Client 5: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 5: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:03:14,806 | client.py:397 | Client 8: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 8: stage 2 completes. uploading masked weights...
# DEBUG flwr 2025-02-21 18:03:14,813 | server_returns_parameters.py:237 | fit_round 3 received 5 results and 5 failures
# DEBUG:flwr:fit_round 3 received 5 results and 5 failures
# INFO flwr 2025-02-21 18:03:14,814 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:03:14,815 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:03:14,816 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:03:14,816 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:03:14,817 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:03:14,818 | strategy.py:186 | Length of content is 4
# INFO:flwr:Length of content is 4
# INFO flwr 2025-02-21 18:03:14,823 | server_returns_parameters.py:171 | evaluate_round 3: no clients selected, cancel
# INFO:flwr:evaluate_round 3: no clients selected, cancel
# INFO flwr 2025-02-21 18:03:14,824 | strategy.py:120 | Configure fit: stage 3, 0, False
# INFO:flwr:Configure fit: stage 3, 0, False
# DEBUG flwr 2025-02-21 18:03:14,825 | server_returns_parameters.py:223 | fit_round 4: strategy sampled 5 clients (out of 3290)
# DEBUG:flwr:fit_round 4: strategy sampled 5 clients (out of 3290)
# INFO flwr 2025-02-21 18:03:14,829 | client.py:146 | CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO:flwr:CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO flwr 2025-02-21 18:03:14,837 | client.py:146 | CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO:flwr:CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO flwr 2025-02-21 18:03:14,839 | client.py:146 | CID 678 reloading from /content/secagg/client_data/678.pth
# INFO:flwr:CID 678 reloading from /content/secagg/client_data/678.pth
# INFO flwr 2025-02-21 18:03:14,843 | client.py:146 | CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO flwr 2025-02-21 18:03:14,849 | client.py:146 | CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO:flwr:CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO:flwr:CID 3175 reloading from /content/secagg/client_data/3175.pth
# DEBUG flwr 2025-02-21 18:03:14,868 | server_returns_parameters.py:237 | fit_round 4 received 5 results and 0 failures
# DEBUG:flwr:fit_round 4 received 5 results and 0 failures
# INFO flwr 2025-02-21 18:03:14,869 | strategy.py:186 | Length of content is 2886
# INFO:flwr:Length of content is 2886
# INFO flwr 2025-02-21 18:03:15,372 | server_returns_parameters.py:171 | evaluate_round 4: no clients selected, cancel
# INFO:flwr:evaluate_round 4: no clients selected, cancel
# INFO flwr 2025-02-21 18:03:15,373 | strategy.py:120 | Configure fit: stage 0, 0, True
# INFO:flwr:Configure fit: stage 0, 0, True
# INFO flwr 2025-02-21 18:03:15,375 | strategy.py:126 | Stage 0
# INFO:flwr:Stage 0
# DEBUG flwr 2025-02-21 18:03:15,378 | server_returns_parameters.py:223 | fit_round 5: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 5: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-21 18:03:15,380 | client.py:181 | Client 1: starting stage 0...
# INFO:flwr:Client 1: starting stage 0...
# INFO flwr 2025-02-21 18:03:15,387 | client.py:181 | Client 2: starting stage 0...
# INFO:flwr:Client 2: starting stage 0...
# INFO flwr 2025-02-21 18:03:15,388 | client.py:181 | Client 0: starting stage 0...
# INFO:flwr:Client 0: starting stage 0...
# INFO flwr 2025-02-21 18:03:15,390 | client.py:181 | Client 3: starting stage 0...
# INFO:flwr:Client 3: starting stage 0...
# INFO flwr 2025-02-21 18:03:15,401 | client.py:209 | Client 0: stage 0 completes. uploading public keys...
# INFO:flwr:Client 0: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:03:15,395 | client.py:181 | Client 5: starting stage 0...
# INFO:flwr:Client 5: starting stage 0...
# INFO flwr 2025-02-21 18:03:15,398 | client.py:209 | Client 2: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:03:15,398 | client.py:209 | Client 1: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:03:15,394 | client.py:181 | Client 4: starting stage 0...
# INFO:flwr:Client 2: stage 0 completes. uploading public keys...
# INFO:flwr:Client 1: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:03:15,411 | client.py:209 | Client 3: stage 0 completes. uploading public keys...
# INFO:flwr:Client 4: starting stage 0...
# INFO flwr 2025-02-21 18:03:15,418 | client.py:181 | Client 6: starting stage 0...
# INFO:flwr:Client 3: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:03:15,422 | client.py:181 | Client 7: starting stage 0...
# INFO:flwr:Client 6: starting stage 0...
# INFO flwr 2025-02-21 18:03:15,426 | client.py:181 | Client 8: starting stage 0...
# INFO:flwr:Client 8: starting stage 0...
# INFO flwr 2025-02-21 18:03:15,435 | client.py:209 | Client 6: stage 0 completes. uploading public keys...
# INFO:flwr:Client 7: starting stage 0...
# INFO:flwr:Client 6: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:03:15,429 | client.py:209 | Client 5: stage 0 completes. uploading public keys...
# INFO:flwr:Client 5: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:03:15,454 | client.py:209 | Client 4: stage 0 completes. uploading public keys...
# INFO:flwr:Client 4: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:03:15,456 | client.py:181 | Client 9: starting stage 0...
# INFO flwr 2025-02-21 18:03:15,458 | client.py:209 | Client 7: stage 0 completes. uploading public keys...
# INFO:flwr:Client 9: starting stage 0...
# INFO:flwr:Client 7: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:03:15,461 | client.py:209 | Client 8: stage 0 completes. uploading public keys...
# INFO:flwr:Client 8: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:03:15,471 | client.py:209 | Client 9: stage 0 completes. uploading public keys...
# INFO:flwr:Client 9: stage 0 completes. uploading public keys...
# DEBUG flwr 2025-02-21 18:03:15,481 | server_returns_parameters.py:237 | fit_round 5 received 10 results and 0 failures
# DEBUG:flwr:fit_round 5 received 10 results and 0 failures
# INFO flwr 2025-02-21 18:03:15,483 | strategy.py:186 | Length of content is 450
# INFO:flwr:Length of content is 450
# INFO flwr 2025-02-21 18:03:15,489 | server_returns_parameters.py:171 | evaluate_round 5: no clients selected, cancel
# INFO:flwr:evaluate_round 5: no clients selected, cancel
# INFO flwr 2025-02-21 18:03:15,490 | strategy.py:120 | Configure fit: stage 1, 0, False
# INFO:flwr:Configure fit: stage 1, 0, False
# DEBUG flwr 2025-02-21 18:03:15,491 | server_returns_parameters.py:223 | fit_round 6: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 6: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-21 18:03:15,492 | client.py:146 | CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO:flwr:CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO flwr 2025-02-21 18:03:15,494 | client.py:146 | CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO flwr 2025-02-21 18:03:15,495 | client.py:146 | CID 839 reloading from /content/secagg/client_data/839.pth
# INFO:flwr:CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO:flwr:CID 839 reloading from /content/secagg/client_data/839.pth
# INFO flwr 2025-02-21 18:03:15,500 | client.py:221 | Client 8: starting stage 1...
# INFO:flwr:Client 8: starting stage 1...
# INFO flwr 2025-02-21 18:03:15,504 | client.py:146 | CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO flwr 2025-02-21 18:03:15,505 | client.py:146 | CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO flwr 2025-02-21 18:03:15,507 | client.py:146 | CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO flwr 2025-02-21 18:03:15,509 | client.py:221 | Client 9: starting stage 1...
# INFO flwr 2025-02-21 18:03:15,510 | client.py:221 | Client 7: starting stage 1...
# INFO:flwr:CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO:flwr:CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO:flwr:CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO flwr 2025-02-21 18:03:15,522 | client.py:221 | Client 0: starting stage 1...
# INFO:flwr:Client 9: starting stage 1...
# INFO:flwr:Client 7: starting stage 1...
# INFO flwr 2025-02-21 18:03:15,525 | client.py:221 | Client 1: starting stage 1...
# INFO:flwr:Client 1: starting stage 1...
# INFO:flwr:Client 0: starting stage 1...
# INFO flwr 2025-02-21 18:03:15,526 | client.py:221 | Client 6: starting stage 1...
# INFO:flwr:Client 6: starting stage 1...
# INFO flwr 2025-02-21 18:03:15,584 | client.py:287 | Client 8: stage 1 completes. uploading key shares...
# INFO:flwr:Client 8: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:03:15,596 | client.py:146 | CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO:flwr:CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO flwr 2025-02-21 18:03:15,605 | client.py:221 | Client 3: starting stage 1...
# INFO:flwr:Client 3: starting stage 1...
# INFO flwr 2025-02-21 18:03:15,663 | client.py:287 | Client 7: stage 1 completes. uploading key shares...
# INFO:flwr:Client 7: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:03:15,669 | client.py:287 | Client 6: stage 1 completes. uploading key shares...
# INFO:flwr:Client 6: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:03:15,684 | client.py:146 | CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO:flwr:CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO flwr 2025-02-21 18:03:15,700 | client.py:221 | Client 4: starting stage 1...
# INFO:flwr:Client 4: starting stage 1...
# INFO flwr 2025-02-21 18:03:15,704 | client.py:146 | CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO:flwr:CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO flwr 2025-02-21 18:03:15,720 | client.py:221 | Client 2: starting stage 1...
# INFO:flwr:Client 2: starting stage 1...
# INFO flwr 2025-02-21 18:03:15,736 | client.py:287 | Client 1: stage 1 completes. uploading key shares...
# INFO:flwr:Client 1: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:03:15,758 | client.py:146 | CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO:flwr:CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO flwr 2025-02-21 18:03:15,759 | client.py:287 | Client 0: stage 1 completes. uploading key shares...
# INFO:flwr:Client 0: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:03:15,768 | client.py:287 | Client 9: stage 1 completes. uploading key shares...
# INFO:flwr:Client 9: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:03:15,780 | client.py:221 | Client 5: starting stage 1...
# INFO flwr 2025-02-21 18:03:15,786 | client.py:287 | Client 3: stage 1 completes. uploading key shares...
# INFO:flwr:Client 5: starting stage 1...
# INFO:flwr:Client 3: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:03:15,813 | client.py:287 | Client 4: stage 1 completes. uploading key shares...
# INFO:flwr:Client 4: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:03:15,838 | client.py:287 | Client 2: stage 1 completes. uploading key shares...
# INFO:flwr:Client 2: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:03:15,853 | client.py:287 | Client 5: stage 1 completes. uploading key shares...
# INFO:flwr:Client 5: stage 1 completes. uploading key shares...
# DEBUG flwr 2025-02-21 18:03:15,860 | server_returns_parameters.py:237 | fit_round 6 received 10 results and 0 failures
# DEBUG:flwr:fit_round 6 received 10 results and 0 failures
# INFO flwr 2025-02-21 18:03:15,863 | strategy.py:186 | Length of content is 7916
# INFO:flwr:Length of content is 7916
# INFO flwr 2025-02-21 18:03:15,867 | server_returns_parameters.py:171 | evaluate_round 6: no clients selected, cancel
# INFO:flwr:evaluate_round 6: no clients selected, cancel
# INFO flwr 2025-02-21 18:03:15,868 | strategy.py:120 | Configure fit: stage 2, 0, False
# INFO:flwr:Configure fit: stage 2, 0, False
# DEBUG flwr 2025-02-21 18:03:15,870 | server_returns_parameters.py:223 | fit_round 7: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 7: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-21 18:03:15,874 | client.py:146 | CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO:flwr:CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO flwr 2025-02-21 18:03:15,877 | client.py:146 | CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO:flwr:CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO flwr 2025-02-21 18:03:15,878 | client.py:146 | CID 839 reloading from /content/secagg/client_data/839.pth
# INFO:flwr:CID 839 reloading from /content/secagg/client_data/839.pth
# INFO flwr 2025-02-21 18:03:15,878 | client.py:146 | CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO:flwr:CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO flwr 2025-02-21 18:03:15,879 | client.py:146 | CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO:flwr:CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO flwr 2025-02-21 18:03:15,880 | client.py:295 | Client 2: starting stage 2...
# INFO:flwr:Client 2: starting stage 2...
# INFO flwr 2025-02-21 18:03:15,881 | client.py:146 | CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO:flwr:CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO flwr 2025-02-21 18:03:15,884 | client.py:295 | Client 8: starting stage 2...
# INFO:flwr:Client 8: starting stage 2...
# INFO flwr 2025-02-21 18:03:15,886 | client.py:295 | Client 7: starting stage 2...
# INFO:flwr:Client 7: starting stage 2...
# INFO flwr 2025-02-21 18:03:15,888 | client.py:295 | Client 3: starting stage 2...
# INFO:flwr:Client 3: starting stage 2...
# INFO flwr 2025-02-21 18:03:15,891 | client.py:295 | Client 4: starting stage 2...
# INFO:flwr:Client 4: starting stage 2...
# INFO flwr 2025-02-21 18:03:15,894 | client.py:146 | CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO:flwr:CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO flwr 2025-02-21 18:03:15,909 | client.py:146 | CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO:flwr:CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO flwr 2025-02-21 18:03:15,912 | client.py:146 | CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO:flwr:CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO flwr 2025-02-21 18:03:15,916 | client.py:295 | Client 5: starting stage 2...
# INFO:flwr:Client 5: starting stage 2...
# INFO flwr 2025-02-21 18:03:15,919 | client.py:295 | Client 6: starting stage 2...
# INFO flwr 2025-02-21 18:03:15,922 | client.py:295 | Client 1: starting stage 2...
# INFO:flwr:Client 6: starting stage 2...
# INFO flwr 2025-02-21 18:03:15,927 | client.py:295 | Client 9: starting stage 2...
# INFO:flwr:Client 1: starting stage 2...
# INFO flwr 2025-02-21 18:03:15,937 | client.py:146 | CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO:flwr:Client 9: starting stage 2...
# INFO:flwr:CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO flwr 2025-02-21 18:03:15,956 | client.py:295 | Client 0: starting stage 2...
# INFO:flwr:Client 0: starting stage 2...
# INFO flwr 2025-02-21 18:03:15,985 | client.py:397 | Client 7: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 7: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:03:15,997 | client.py:397 | Client 9: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 9: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:03:16,015 | client.py:397 | Client 6: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 6: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:03:16,022 | client.py:397 | Client 8: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 8: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:03:16,023 | client.py:397 | Client 5: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 5: stage 2 completes. uploading masked weights...
# DEBUG flwr 2025-02-21 18:03:16,038 | server_returns_parameters.py:237 | fit_round 7 received 5 results and 5 failures
# DEBUG:flwr:fit_round 7 received 5 results and 5 failures
# INFO flwr 2025-02-21 18:03:16,040 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:03:16,041 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:03:16,042 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:03:16,043 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:03:16,044 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:03:16,044 | strategy.py:186 | Length of content is 4
# INFO:flwr:Length of content is 4
# INFO flwr 2025-02-21 18:03:16,047 | server_returns_parameters.py:171 | evaluate_round 7: no clients selected, cancel
# INFO:flwr:evaluate_round 7: no clients selected, cancel
# INFO flwr 2025-02-21 18:03:16,048 | strategy.py:120 | Configure fit: stage 3, 0, False
# INFO:flwr:Configure fit: stage 3, 0, False
# DEBUG flwr 2025-02-21 18:03:16,049 | server_returns_parameters.py:223 | fit_round 8: strategy sampled 5 clients (out of 3290)
# DEBUG:flwr:fit_round 8: strategy sampled 5 clients (out of 3290)
# INFO flwr 2025-02-21 18:03:16,054 | client.py:146 | CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO:flwr:CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO flwr 2025-02-21 18:03:16,059 | client.py:146 | CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO:flwr:CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO flwr 2025-02-21 18:03:16,060 | client.py:146 | CID 839 reloading from /content/secagg/client_data/839.pth
# INFO:flwr:CID 839 reloading from /content/secagg/client_data/839.pth
# INFO flwr 2025-02-21 18:03:16,061 | client.py:146 | CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO:flwr:CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO flwr 2025-02-21 18:03:16,062 | client.py:146 | CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO:flwr:CID 3119 reloading from /content/secagg/client_data/3119.pth
# DEBUG flwr 2025-02-21 18:03:16,098 | server_returns_parameters.py:237 | fit_round 8 received 5 results and 0 failures
# DEBUG:flwr:fit_round 8 received 5 results and 0 failures
# INFO flwr 2025-02-21 18:03:16,100 | strategy.py:186 | Length of content is 2886
# INFO:flwr:Length of content is 2886
# INFO flwr 2025-02-21 18:03:16,436 | server_returns_parameters.py:171 | evaluate_round 8: no clients selected, cancel
# INFO:flwr:evaluate_round 8: no clients selected, cancel
# INFO flwr 2025-02-21 18:03:16,440 | server_returns_parameters.py:150 | FL finished in 2.477927803
# INFO:flwr:FL finished in 2.477927803
# INFO flwr 2025-02-21 18:03:16,443 | app.py:250 | app_fit: losses_distributed []
# INFO:flwr:app_fit: losses_distributed []
# INFO flwr 2025-02-21 18:03:16,444 | app.py:251 | app_fit: metrics_distributed_fit {'total_cost': [(1, 4500), (2, 79160), (3, 401340), (4, 14430), (5, 4500), (6, 79160), (7, 401340), (8, 14430)]}
# INFO:flwr:app_fit: metrics_distributed_fit {'total_cost': [(1, 4500), (2, 79160), (3, 401340), (4, 14430), (5, 4500), (6, 79160), (7, 401340), (8, 14430)]}
# INFO flwr 2025-02-21 18:03:16,446 | app.py:252 | app_fit: metrics_distributed {}
# INFO:flwr:app_fit: metrics_distributed {}
# INFO flwr 2025-02-21 18:03:16,448 | app.py:253 | app_fit: losses_centralized []
# INFO:flwr:app_fit: losses_centralized []
# INFO flwr 2025-02-21 18:03:16,449 | app.py:254 | app_fit: metrics_centralized {}
# INFO:flwr:app_fit: metrics_centralized {}

# %%
secagg_hist
# Out:
# History (metrics, distributed, fit):
# {'total_cost': [(1, 4500), (2, 79160), (3, 401340), (4, 14430), (5, 4500), (6, 79160), (7, 401340), (8, 14430)]}

# %% [markdown]
# Looking carefully at the `History` object returned by the simulation, we can see that it contains the key `total_cost`, which couples the round of communication with the number of bytes exchanged during that round.
# Note that the values are periodic because of the 4 phases involved in the protocol.

# %% [markdown]
# **Question 9 (Part II ✅ | Part III/MPhil ✅):**
#
# (You need to provide the answer with **code** and **plots** for this question. A short written argumentation is recommended.)
#
# Using the function `run_SA_demo`, study the impact of different parameters on the `total_cost`:
#
# 1. Draw a scatter plot with the `total_cost` summed across rounds on the y-axis. While keeping all other parameters constant to the above values, vary the `num_clients_per_round` from 10 to 40 using an increment of 10. Use the `num_clients_per_round` as the x-axis.
#
# 2. Draw a scatter plot with the `total_cost` summed across rounds on the y-axis. While keeping all other parameters constant to the above values, vary `n_model_parameters` between $2^{10}$ and $2^{15}$ increasing using all the powers of two in the interval. Use the `n_model_parameters` as the x-axis.
#
# 3. Describe the trade-offs you see and how they relate to communication overheads.

# %% [markdown]
# ---
#
# #### **Answer to Question 9**

# %%
num_clients_per_round_list = [10, 20, 30, 40]

results = {num_clients_per_round: [] for num_clients_per_round in num_clients_per_round_list}

for num_clients_per_round in num_clients_per_round_list:
    params, hist = run_sec_agg_demo(num_clients_per_round=num_clients_per_round)

    results[num_clients_per_round] = [params, hist]
# Out:
# INFO flwr 2025-02-21 18:51:20,288 | app.py:149 | Starting Flower simulation, config: ServerConfig(num_rounds=8, round_timeout=None)
# INFO:flwr:Starting Flower simulation, config: ServerConfig(num_rounds=8, round_timeout=None)
# INFO flwr 2025-02-21 18:51:20,300 | server_returns_parameters.py:81 | Initializing global parameters
# INFO:flwr:Initializing global parameters
# INFO flwr 2025-02-21 18:51:20,303 | server_returns_parameters.py:273 | Using initial parameters provided by strategy
# INFO:flwr:Using initial parameters provided by strategy
# INFO flwr 2025-02-21 18:51:20,305 | server_returns_parameters.py:84 | Evaluating initial parameters
# INFO:flwr:Evaluating initial parameters
# INFO flwr 2025-02-21 18:51:20,307 | server_returns_parameters.py:97 | FL starting
# INFO:flwr:FL starting
# INFO flwr 2025-02-21 18:51:20,309 | strategy.py:120 | Configure fit: stage 0, 0, True
# INFO:flwr:Configure fit: stage 0, 0, True
# INFO flwr 2025-02-21 18:51:20,311 | strategy.py:126 | Stage 0
# INFO:flwr:Stage 0
# DEBUG flwr 2025-02-21 18:51:20,314 | server_returns_parameters.py:223 | fit_round 1: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 1: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-21 18:51:20,317 | client.py:181 | Client 1: starting stage 0...
# INFO:flwr:Client 1: starting stage 0...
# INFO flwr 2025-02-21 18:51:20,320 | client.py:181 | Client 0: starting stage 0...
# INFO:flwr:Client 0: starting stage 0...
# INFO flwr 2025-02-21 18:51:20,322 | client.py:181 | Client 2: starting stage 0...
# INFO:flwr:Client 2: starting stage 0...
# INFO flwr 2025-02-21 18:51:20,323 | client.py:181 | Client 3: starting stage 0...
# INFO:flwr:Client 3: starting stage 0...
# INFO flwr 2025-02-21 18:51:20,337 | client.py:209 | Client 3: stage 0 completes. uploading public keys...
# INFO:flwr:Client 3: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:20,333 | client.py:209 | Client 1: stage 0 completes. uploading public keys...
# INFO:flwr:Client 1: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:20,331 | client.py:181 | Client 4: starting stage 0...
# INFO flwr 2025-02-21 18:51:20,339 | client.py:181 | Client 5: starting stage 0...
# INFO flwr 2025-02-21 18:51:20,342 | client.py:209 | Client 0: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:20,342 | client.py:209 | Client 2: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:20,347 | client.py:181 | Client 6: starting stage 0...
# INFO:flwr:Client 4: starting stage 0...
# INFO:flwr:Client 5: starting stage 0...
# INFO:flwr:Client 0: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:20,354 | client.py:181 | Client 7: starting stage 0...
# INFO:flwr:Client 7: starting stage 0...
# INFO flwr 2025-02-21 18:51:20,355 | client.py:209 | Client 5: stage 0 completes. uploading public keys...
# INFO:flwr:Client 6: starting stage 0...
# INFO flwr 2025-02-21 18:51:20,356 | client.py:209 | Client 4: stage 0 completes. uploading public keys...
# INFO:flwr:Client 2: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:20,357 | client.py:181 | Client 8: starting stage 0...
# INFO:flwr:Client 8: starting stage 0...
# INFO flwr 2025-02-21 18:51:20,364 | client.py:209 | Client 7: stage 0 completes. uploading public keys...
# INFO:flwr:Client 4: stage 0 completes. uploading public keys...
# INFO:flwr:Client 5: stage 0 completes. uploading public keys...
# INFO:flwr:Client 7: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:20,368 | client.py:209 | Client 6: stage 0 completes. uploading public keys...
# INFO:flwr:Client 6: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:20,372 | client.py:209 | Client 8: stage 0 completes. uploading public keys...
# INFO:flwr:Client 8: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:20,372 | client.py:181 | Client 9: starting stage 0...
# INFO:flwr:Client 9: starting stage 0...
# INFO flwr 2025-02-21 18:51:20,393 | client.py:209 | Client 9: stage 0 completes. uploading public keys...
# INFO:flwr:Client 9: stage 0 completes. uploading public keys...
# DEBUG flwr 2025-02-21 18:51:20,399 | server_returns_parameters.py:237 | fit_round 1 received 10 results and 0 failures
# DEBUG:flwr:fit_round 1 received 10 results and 0 failures
# INFO flwr 2025-02-21 18:51:20,400 | strategy.py:186 | Length of content is 450
# INFO:flwr:Length of content is 450
# INFO flwr 2025-02-21 18:51:20,402 | server_returns_parameters.py:171 | evaluate_round 1: no clients selected, cancel
# INFO:flwr:evaluate_round 1: no clients selected, cancel
# INFO flwr 2025-02-21 18:51:20,404 | strategy.py:120 | Configure fit: stage 1, 0, False
# INFO:flwr:Configure fit: stage 1, 0, False
# DEBUG flwr 2025-02-21 18:51:20,405 | server_returns_parameters.py:223 | fit_round 2: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 2: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-21 18:51:20,406 | client.py:146 | CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO:flwr:CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO flwr 2025-02-21 18:51:20,408 | client.py:146 | CID 678 reloading from /content/secagg/client_data/678.pth
# INFO:flwr:CID 678 reloading from /content/secagg/client_data/678.pth
# INFO flwr 2025-02-21 18:51:20,411 | client.py:146 | CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO:flwr:CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO flwr 2025-02-21 18:51:20,411 | client.py:146 | CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO flwr 2025-02-21 18:51:20,412 | client.py:146 | CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO:flwr:CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO flwr 2025-02-21 18:51:20,415 | client.py:146 | CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO:flwr:CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO:flwr:CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO flwr 2025-02-21 18:51:20,419 | client.py:221 | Client 7: starting stage 1...
# INFO flwr 2025-02-21 18:51:20,422 | client.py:221 | Client 5: starting stage 1...
# INFO flwr 2025-02-21 18:51:20,423 | client.py:221 | Client 9: starting stage 1...
# INFO:flwr:Client 7: starting stage 1...
# INFO flwr 2025-02-21 18:51:20,423 | client.py:221 | Client 2: starting stage 1...
# INFO:flwr:Client 5: starting stage 1...
# INFO flwr 2025-02-21 18:51:20,429 | client.py:221 | Client 6: starting stage 1...
# INFO flwr 2025-02-21 18:51:20,432 | client.py:221 | Client 0: starting stage 1...
# INFO:flwr:Client 9: starting stage 1...
# INFO:flwr:Client 2: starting stage 1...
# INFO:flwr:Client 6: starting stage 1...
# INFO:flwr:Client 0: starting stage 1...
# INFO flwr 2025-02-21 18:51:20,599 | client.py:287 | Client 9: stage 1 completes. uploading key shares...
# INFO:flwr:Client 9: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:51:20,612 | client.py:287 | Client 5: stage 1 completes. uploading key shares...
# INFO:flwr:Client 5: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:51:20,620 | client.py:287 | Client 7: stage 1 completes. uploading key shares...
# INFO:flwr:Client 7: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:51:20,626 | client.py:146 | CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO:flwr:CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO flwr 2025-02-21 18:51:20,631 | client.py:146 | CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO:flwr:CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO flwr 2025-02-21 18:51:20,633 | client.py:221 | Client 3: starting stage 1...
# INFO:flwr:Client 3: starting stage 1...
# INFO flwr 2025-02-21 18:51:20,642 | client.py:287 | Client 0: stage 1 completes. uploading key shares...
# INFO:flwr:Client 0: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:51:20,645 | client.py:146 | CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO:flwr:CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO flwr 2025-02-21 18:51:20,645 | client.py:221 | Client 4: starting stage 1...
# INFO:flwr:Client 4: starting stage 1...
# INFO flwr 2025-02-21 18:51:20,658 | client.py:146 | CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO:flwr:CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO flwr 2025-02-21 18:51:20,670 | client.py:221 | Client 8: starting stage 1...
# INFO:flwr:Client 8: starting stage 1...
# INFO flwr 2025-02-21 18:51:20,698 | client.py:221 | Client 1: starting stage 1...
# INFO:flwr:Client 1: starting stage 1...
# INFO flwr 2025-02-21 18:51:20,702 | client.py:287 | Client 2: stage 1 completes. uploading key shares...
# INFO:flwr:Client 2: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:51:20,716 | client.py:287 | Client 6: stage 1 completes. uploading key shares...
# INFO:flwr:Client 6: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:51:20,790 | client.py:287 | Client 1: stage 1 completes. uploading key shares...
# INFO:flwr:Client 1: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:51:20,860 | client.py:287 | Client 3: stage 1 completes. uploading key shares...
# INFO:flwr:Client 3: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:51:20,880 | client.py:287 | Client 4: stage 1 completes. uploading key shares...
# INFO:flwr:Client 4: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:51:20,889 | client.py:287 | Client 8: stage 1 completes. uploading key shares...
# INFO:flwr:Client 8: stage 1 completes. uploading key shares...
# DEBUG flwr 2025-02-21 18:51:20,902 | server_returns_parameters.py:237 | fit_round 2 received 10 results and 0 failures
# DEBUG:flwr:fit_round 2 received 10 results and 0 failures
# INFO flwr 2025-02-21 18:51:20,904 | strategy.py:186 | Length of content is 7916
# INFO:flwr:Length of content is 7916
# INFO flwr 2025-02-21 18:51:20,905 | server_returns_parameters.py:171 | evaluate_round 2: no clients selected, cancel
# INFO:flwr:evaluate_round 2: no clients selected, cancel
# INFO flwr 2025-02-21 18:51:20,906 | strategy.py:120 | Configure fit: stage 2, 0, False
# INFO:flwr:Configure fit: stage 2, 0, False
# DEBUG flwr 2025-02-21 18:51:20,908 | server_returns_parameters.py:223 | fit_round 3: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 3: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-21 18:51:20,910 | client.py:146 | CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO:flwr:CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO flwr 2025-02-21 18:51:20,915 | client.py:146 | CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO:flwr:CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO flwr 2025-02-21 18:51:20,919 | client.py:295 | Client 4: starting stage 2...
# INFO:flwr:Client 4: starting stage 2...
# INFO flwr 2025-02-21 18:51:20,920 | client.py:146 | CID 678 reloading from /content/secagg/client_data/678.pth
# INFO:flwr:CID 678 reloading from /content/secagg/client_data/678.pth
# INFO flwr 2025-02-21 18:51:20,921 | client.py:295 | Client 8: starting stage 2...
# INFO flwr 2025-02-21 18:51:20,929 | client.py:146 | CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO:flwr:Client 8: starting stage 2...
# INFO flwr 2025-02-21 18:51:20,932 | client.py:295 | Client 7: starting stage 2...
# INFO:flwr:CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO:flwr:Client 7: starting stage 2...
# INFO flwr 2025-02-21 18:51:20,932 | client.py:146 | CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO:flwr:CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO flwr 2025-02-21 18:51:20,933 | client.py:146 | CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO flwr 2025-02-21 18:51:20,934 | client.py:146 | CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO:flwr:CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO flwr 2025-02-21 18:51:20,943 | client.py:295 | Client 3: starting stage 2...
# INFO:flwr:CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO:flwr:Client 3: starting stage 2...
# INFO flwr 2025-02-21 18:51:20,959 | client.py:295 | Client 9: starting stage 2...
# INFO:flwr:Client 9: starting stage 2...
# INFO flwr 2025-02-21 18:51:20,963 | client.py:295 | Client 1: starting stage 2...
# INFO:flwr:Client 1: starting stage 2...
# INFO flwr 2025-02-21 18:51:20,965 | client.py:295 | Client 2: starting stage 2...
# INFO:flwr:Client 2: starting stage 2...
# INFO flwr 2025-02-21 18:51:20,970 | client.py:146 | CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO:flwr:CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO flwr 2025-02-21 18:51:20,987 | client.py:146 | CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO:flwr:CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO flwr 2025-02-21 18:51:20,995 | client.py:146 | CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO:flwr:CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO flwr 2025-02-21 18:51:21,003 | client.py:295 | Client 5: starting stage 2...
# INFO:flwr:Client 5: starting stage 2...
# INFO flwr 2025-02-21 18:51:21,006 | client.py:295 | Client 6: starting stage 2...
# INFO:flwr:Client 6: starting stage 2...
# INFO flwr 2025-02-21 18:51:21,008 | client.py:295 | Client 0: starting stage 2...
# INFO:flwr:Client 0: starting stage 2...
# INFO flwr 2025-02-21 18:51:21,022 | client.py:397 | Client 7: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 7: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:51:21,024 | client.py:397 | Client 8: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 8: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:51:21,080 | client.py:397 | Client 6: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 6: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:51:21,097 | client.py:397 | Client 9: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 9: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:51:21,097 | client.py:397 | Client 5: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 5: stage 2 completes. uploading masked weights...
# DEBUG flwr 2025-02-21 18:51:21,116 | server_returns_parameters.py:237 | fit_round 3 received 5 results and 5 failures
# DEBUG:flwr:fit_round 3 received 5 results and 5 failures
# INFO flwr 2025-02-21 18:51:21,117 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:51:21,117 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:51:21,118 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:51:21,119 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:51:21,122 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:51:21,123 | strategy.py:186 | Length of content is 4
# INFO:flwr:Length of content is 4
# INFO flwr 2025-02-21 18:51:21,127 | server_returns_parameters.py:171 | evaluate_round 3: no clients selected, cancel
# INFO:flwr:evaluate_round 3: no clients selected, cancel
# INFO flwr 2025-02-21 18:51:21,128 | strategy.py:120 | Configure fit: stage 3, 0, False
# INFO:flwr:Configure fit: stage 3, 0, False
# DEBUG flwr 2025-02-21 18:51:21,131 | server_returns_parameters.py:223 | fit_round 4: strategy sampled 5 clients (out of 3290)
# DEBUG:flwr:fit_round 4: strategy sampled 5 clients (out of 3290)
# INFO flwr 2025-02-21 18:51:21,135 | client.py:146 | CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO:flwr:CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO flwr 2025-02-21 18:51:21,143 | client.py:146 | CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO:flwr:CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO flwr 2025-02-21 18:51:21,148 | client.py:146 | CID 678 reloading from /content/secagg/client_data/678.pth
# INFO:flwr:CID 678 reloading from /content/secagg/client_data/678.pth
# INFO flwr 2025-02-21 18:51:21,162 | client.py:146 | CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO:flwr:CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO flwr 2025-02-21 18:51:21,168 | client.py:146 | CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO:flwr:CID 2399 reloading from /content/secagg/client_data/2399.pth
# DEBUG flwr 2025-02-21 18:51:21,181 | server_returns_parameters.py:237 | fit_round 4 received 5 results and 0 failures
# DEBUG:flwr:fit_round 4 received 5 results and 0 failures
# INFO flwr 2025-02-21 18:51:21,182 | strategy.py:186 | Length of content is 2886
# INFO:flwr:Length of content is 2886
# INFO flwr 2025-02-21 18:51:21,770 | server_returns_parameters.py:171 | evaluate_round 4: no clients selected, cancel
# INFO:flwr:evaluate_round 4: no clients selected, cancel
# INFO flwr 2025-02-21 18:51:21,775 | strategy.py:120 | Configure fit: stage 0, 0, True
# INFO:flwr:Configure fit: stage 0, 0, True
# INFO flwr 2025-02-21 18:51:21,776 | strategy.py:126 | Stage 0
# INFO:flwr:Stage 0
# DEBUG flwr 2025-02-21 18:51:21,777 | server_returns_parameters.py:223 | fit_round 5: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 5: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-21 18:51:21,783 | client.py:181 | Client 1: starting stage 0...
# INFO:flwr:Client 1: starting stage 0...
# INFO flwr 2025-02-21 18:51:21,784 | client.py:181 | Client 2: starting stage 0...
# INFO:flwr:Client 2: starting stage 0...
# INFO flwr 2025-02-21 18:51:21,794 | client.py:209 | Client 1: stage 0 completes. uploading public keys...
# INFO:flwr:Client 1: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:21,799 | client.py:209 | Client 2: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:21,788 | client.py:181 | Client 0: starting stage 0...
# INFO flwr 2025-02-21 18:51:21,788 | client.py:181 | Client 3: starting stage 0...
# INFO:flwr:Client 2: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:21,785 | client.py:181 | Client 4: starting stage 0...
# INFO:flwr:Client 0: starting stage 0...
# INFO:flwr:Client 3: starting stage 0...
# INFO flwr 2025-02-21 18:51:21,786 | client.py:181 | Client 5: starting stage 0...
# INFO:flwr:Client 5: starting stage 0...
# INFO flwr 2025-02-21 18:51:21,809 | client.py:181 | Client 6: starting stage 0...
# INFO flwr 2025-02-21 18:51:21,812 | client.py:181 | Client 7: starting stage 0...
# INFO flwr 2025-02-21 18:51:21,818 | client.py:209 | Client 0: stage 0 completes. uploading public keys...
# INFO:flwr:Client 4: starting stage 0...
# INFO flwr 2025-02-21 18:51:21,822 | client.py:209 | Client 3: stage 0 completes. uploading public keys...
# INFO:flwr:Client 6: starting stage 0...
# INFO flwr 2025-02-21 18:51:21,837 | client.py:209 | Client 4: stage 0 completes. uploading public keys...
# INFO:flwr:Client 7: starting stage 0...
# INFO flwr 2025-02-21 18:51:21,842 | client.py:209 | Client 6: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:21,847 | client.py:209 | Client 5: stage 0 completes. uploading public keys...
# INFO:flwr:Client 0: stage 0 completes. uploading public keys...
# INFO:flwr:Client 3: stage 0 completes. uploading public keys...
# INFO:flwr:Client 4: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:21,864 | client.py:181 | Client 9: starting stage 0...
# INFO:flwr:Client 6: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:21,858 | client.py:181 | Client 8: starting stage 0...
# INFO:flwr:Client 5: stage 0 completes. uploading public keys...
# INFO:flwr:Client 9: starting stage 0...
# INFO:flwr:Client 8: starting stage 0...
# INFO flwr 2025-02-21 18:51:21,855 | client.py:209 | Client 7: stage 0 completes. uploading public keys...
# INFO:flwr:Client 7: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:21,878 | client.py:209 | Client 8: stage 0 completes. uploading public keys...
# INFO:flwr:Client 8: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:21,886 | client.py:209 | Client 9: stage 0 completes. uploading public keys...
# INFO:flwr:Client 9: stage 0 completes. uploading public keys...
# DEBUG flwr 2025-02-21 18:51:21,893 | server_returns_parameters.py:237 | fit_round 5 received 10 results and 0 failures
# DEBUG:flwr:fit_round 5 received 10 results and 0 failures
# INFO flwr 2025-02-21 18:51:21,894 | strategy.py:186 | Length of content is 450
# INFO:flwr:Length of content is 450
# INFO flwr 2025-02-21 18:51:21,895 | server_returns_parameters.py:171 | evaluate_round 5: no clients selected, cancel
# INFO:flwr:evaluate_round 5: no clients selected, cancel
# INFO flwr 2025-02-21 18:51:21,896 | strategy.py:120 | Configure fit: stage 1, 0, False
# INFO:flwr:Configure fit: stage 1, 0, False
# DEBUG flwr 2025-02-21 18:51:21,897 | server_returns_parameters.py:223 | fit_round 6: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 6: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-21 18:51:21,902 | client.py:146 | CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO:flwr:CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO flwr 2025-02-21 18:51:21,906 | client.py:146 | CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO:flwr:CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO flwr 2025-02-21 18:51:21,908 | client.py:221 | Client 6: starting stage 1...
# INFO:flwr:Client 6: starting stage 1...
# INFO flwr 2025-02-21 18:51:21,910 | client.py:221 | Client 0: starting stage 1...
# INFO:flwr:Client 0: starting stage 1...
# INFO flwr 2025-02-21 18:51:21,912 | client.py:146 | CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO flwr 2025-02-21 18:51:21,913 | client.py:146 | CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO flwr 2025-02-21 18:51:21,916 | client.py:146 | CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO flwr 2025-02-21 18:51:21,920 | client.py:146 | CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO:flwr:CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO:flwr:CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO flwr 2025-02-21 18:51:21,932 | client.py:221 | Client 8: starting stage 1...
# INFO:flwr:CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO flwr 2025-02-21 18:51:21,937 | client.py:221 | Client 2: starting stage 1...
# INFO flwr 2025-02-21 18:51:21,943 | client.py:221 | Client 3: starting stage 1...
# INFO:flwr:CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO flwr 2025-02-21 18:51:21,950 | client.py:221 | Client 5: starting stage 1...
# INFO:flwr:Client 8: starting stage 1...
# INFO:flwr:Client 2: starting stage 1...
# INFO:flwr:Client 3: starting stage 1...
# INFO:flwr:Client 5: starting stage 1...
# INFO flwr 2025-02-21 18:51:22,003 | client.py:287 | Client 6: stage 1 completes. uploading key shares...
# INFO:flwr:Client 6: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:51:22,012 | client.py:146 | CID 839 reloading from /content/secagg/client_data/839.pth
# INFO:flwr:CID 839 reloading from /content/secagg/client_data/839.pth
# INFO flwr 2025-02-21 18:51:22,032 | client.py:221 | Client 7: starting stage 1...
# INFO:flwr:Client 7: starting stage 1...
# INFO flwr 2025-02-21 18:51:22,103 | client.py:287 | Client 5: stage 1 completes. uploading key shares...
# INFO:flwr:Client 5: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:51:22,107 | client.py:287 | Client 0: stage 1 completes. uploading key shares...
# INFO:flwr:Client 0: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:51:22,119 | client.py:146 | CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO:flwr:CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO flwr 2025-02-21 18:51:22,129 | client.py:146 | CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO:flwr:CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO flwr 2025-02-21 18:51:22,138 | client.py:221 | Client 4: starting stage 1...
# INFO:flwr:Client 4: starting stage 1...
# INFO flwr 2025-02-21 18:51:22,158 | client.py:221 | Client 9: starting stage 1...
# INFO:flwr:Client 9: starting stage 1...
# INFO flwr 2025-02-21 18:51:22,180 | client.py:287 | Client 2: stage 1 completes. uploading key shares...
# INFO:flwr:Client 2: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:51:22,192 | client.py:146 | CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO:flwr:CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO flwr 2025-02-21 18:51:22,198 | client.py:221 | Client 1: starting stage 1...
# INFO:flwr:Client 1: starting stage 1...
# INFO flwr 2025-02-21 18:51:22,212 | client.py:287 | Client 3: stage 1 completes. uploading key shares...
# INFO:flwr:Client 3: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:51:22,297 | client.py:287 | Client 7: stage 1 completes. uploading key shares...
# INFO:flwr:Client 7: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:51:22,334 | client.py:287 | Client 8: stage 1 completes. uploading key shares...
# INFO:flwr:Client 8: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:51:22,352 | client.py:287 | Client 9: stage 1 completes. uploading key shares...
# INFO:flwr:Client 9: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:51:22,421 | client.py:287 | Client 1: stage 1 completes. uploading key shares...
# INFO:flwr:Client 1: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:51:22,430 | client.py:287 | Client 4: stage 1 completes. uploading key shares...
# INFO:flwr:Client 4: stage 1 completes. uploading key shares...
# DEBUG flwr 2025-02-21 18:51:22,438 | server_returns_parameters.py:237 | fit_round 6 received 10 results and 0 failures
# DEBUG:flwr:fit_round 6 received 10 results and 0 failures
# INFO flwr 2025-02-21 18:51:22,440 | strategy.py:186 | Length of content is 7916
# INFO:flwr:Length of content is 7916
# INFO flwr 2025-02-21 18:51:22,443 | server_returns_parameters.py:171 | evaluate_round 6: no clients selected, cancel
# INFO:flwr:evaluate_round 6: no clients selected, cancel
# INFO flwr 2025-02-21 18:51:22,444 | strategy.py:120 | Configure fit: stage 2, 0, False
# INFO:flwr:Configure fit: stage 2, 0, False
# DEBUG flwr 2025-02-21 18:51:22,446 | server_returns_parameters.py:223 | fit_round 7: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 7: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-21 18:51:22,447 | client.py:146 | CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO:flwr:CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO flwr 2025-02-21 18:51:22,449 | client.py:146 | CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO:flwr:CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO flwr 2025-02-21 18:51:22,452 | client.py:295 | Client 0: starting stage 2...
# INFO flwr 2025-02-21 18:51:22,454 | client.py:146 | CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO:flwr:Client 0: starting stage 2...
# INFO flwr 2025-02-21 18:51:22,456 | client.py:146 | CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO:flwr:CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO:flwr:CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO flwr 2025-02-21 18:51:22,456 | client.py:146 | CID 839 reloading from /content/secagg/client_data/839.pth
# INFO:flwr:CID 839 reloading from /content/secagg/client_data/839.pth
# INFO flwr 2025-02-21 18:51:22,461 | client.py:295 | Client 1: starting stage 2...
# INFO flwr 2025-02-21 18:51:22,472 | client.py:295 | Client 7: starting stage 2...
# INFO:flwr:Client 1: starting stage 2...
# INFO:flwr:Client 7: starting stage 2...
# INFO flwr 2025-02-21 18:51:22,464 | client.py:295 | Client 9: starting stage 2...
# INFO flwr 2025-02-21 18:51:22,464 | client.py:295 | Client 4: starting stage 2...
# INFO flwr 2025-02-21 18:51:22,462 | client.py:146 | CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO:flwr:Client 9: starting stage 2...
# INFO:flwr:CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO flwr 2025-02-21 18:51:22,474 | client.py:146 | CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO:flwr:Client 4: starting stage 2...
# INFO flwr 2025-02-21 18:51:22,474 | client.py:146 | CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO:flwr:CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO flwr 2025-02-21 18:51:22,493 | client.py:146 | CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO:flwr:CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO:flwr:CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO flwr 2025-02-21 18:51:22,498 | client.py:295 | Client 3: starting stage 2...
# INFO:flwr:Client 3: starting stage 2...
# INFO flwr 2025-02-21 18:51:22,504 | client.py:295 | Client 6: starting stage 2...
# INFO:flwr:Client 6: starting stage 2...
# INFO flwr 2025-02-21 18:51:22,505 | client.py:295 | Client 2: starting stage 2...
# INFO flwr 2025-02-21 18:51:22,511 | client.py:295 | Client 5: starting stage 2...
# INFO:flwr:Client 2: starting stage 2...
# INFO:flwr:Client 5: starting stage 2...
# INFO flwr 2025-02-21 18:51:22,512 | client.py:146 | CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO:flwr:CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO flwr 2025-02-21 18:51:22,537 | client.py:295 | Client 8: starting stage 2...
# INFO:flwr:Client 8: starting stage 2...
# INFO flwr 2025-02-21 18:51:22,580 | client.py:397 | Client 6: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 6: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:51:22,583 | client.py:397 | Client 5: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:51:22,585 | client.py:397 | Client 7: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 5: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 7: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:51:22,601 | client.py:397 | Client 8: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 8: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:51:22,608 | client.py:397 | Client 9: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 9: stage 2 completes. uploading masked weights...
# DEBUG flwr 2025-02-21 18:51:22,617 | server_returns_parameters.py:237 | fit_round 7 received 5 results and 5 failures
# DEBUG:flwr:fit_round 7 received 5 results and 5 failures
# INFO flwr 2025-02-21 18:51:22,620 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:51:22,623 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:51:22,625 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:51:22,630 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:51:22,631 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:51:22,632 | strategy.py:186 | Length of content is 4
# INFO:flwr:Length of content is 4
# INFO flwr 2025-02-21 18:51:22,634 | server_returns_parameters.py:171 | evaluate_round 7: no clients selected, cancel
# INFO:flwr:evaluate_round 7: no clients selected, cancel
# INFO flwr 2025-02-21 18:51:22,636 | strategy.py:120 | Configure fit: stage 3, 0, False
# INFO:flwr:Configure fit: stage 3, 0, False
# DEBUG flwr 2025-02-21 18:51:22,637 | server_returns_parameters.py:223 | fit_round 8: strategy sampled 5 clients (out of 3290)
# DEBUG:flwr:fit_round 8: strategy sampled 5 clients (out of 3290)
# INFO flwr 2025-02-21 18:51:22,640 | client.py:146 | CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO:flwr:CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO flwr 2025-02-21 18:51:22,642 | client.py:146 | CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO:flwr:CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO flwr 2025-02-21 18:51:22,652 | client.py:146 | CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO:flwr:CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO flwr 2025-02-21 18:51:22,661 | client.py:146 | CID 839 reloading from /content/secagg/client_data/839.pth
# INFO:flwr:CID 839 reloading from /content/secagg/client_data/839.pth
# INFO flwr 2025-02-21 18:51:22,671 | client.py:146 | CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO:flwr:CID 3119 reloading from /content/secagg/client_data/3119.pth
# DEBUG flwr 2025-02-21 18:51:22,681 | server_returns_parameters.py:237 | fit_round 8 received 5 results and 0 failures
# DEBUG:flwr:fit_round 8 received 5 results and 0 failures
# INFO flwr 2025-02-21 18:51:22,682 | strategy.py:186 | Length of content is 2886
# INFO:flwr:Length of content is 2886
# INFO flwr 2025-02-21 18:51:22,991 | server_returns_parameters.py:171 | evaluate_round 8: no clients selected, cancel
# INFO:flwr:evaluate_round 8: no clients selected, cancel
# INFO flwr 2025-02-21 18:51:22,993 | server_returns_parameters.py:150 | FL finished in 2.6837290260000373
# INFO:flwr:FL finished in 2.6837290260000373
# INFO flwr 2025-02-21 18:51:22,995 | app.py:250 | app_fit: losses_distributed []
# INFO:flwr:app_fit: losses_distributed []
# INFO flwr 2025-02-21 18:51:22,996 | app.py:251 | app_fit: metrics_distributed_fit {'total_cost': [(1, 4500), (2, 79160), (3, 401340), (4, 14430), (5, 4500), (6, 79160), (7, 401340), (8, 14430)]}
# INFO:flwr:app_fit: metrics_distributed_fit {'total_cost': [(1, 4500), (2, 79160), (3, 401340), (4, 14430), (5, 4500), (6, 79160), (7, 401340), (8, 14430)]}
# INFO flwr 2025-02-21 18:51:22,997 | app.py:252 | app_fit: metrics_distributed {}
# INFO:flwr:app_fit: metrics_distributed {}
# INFO flwr 2025-02-21 18:51:22,998 | app.py:253 | app_fit: losses_centralized []
# INFO:flwr:app_fit: losses_centralized []
# INFO flwr 2025-02-21 18:51:22,999 | app.py:254 | app_fit: metrics_centralized {}
# INFO:flwr:app_fit: metrics_centralized {}
# INFO flwr 2025-02-21 18:51:23,065 | app.py:149 | Starting Flower simulation, config: ServerConfig(num_rounds=8, round_timeout=None)
# INFO:flwr:Starting Flower simulation, config: ServerConfig(num_rounds=8, round_timeout=None)
# INFO flwr 2025-02-21 18:51:23,076 | server_returns_parameters.py:81 | Initializing global parameters
# INFO:flwr:Initializing global parameters
# INFO flwr 2025-02-21 18:51:23,081 | server_returns_parameters.py:273 | Using initial parameters provided by strategy
# INFO:flwr:Using initial parameters provided by strategy
# INFO flwr 2025-02-21 18:51:23,082 | server_returns_parameters.py:84 | Evaluating initial parameters
# INFO:flwr:Evaluating initial parameters
# INFO flwr 2025-02-21 18:51:23,084 | server_returns_parameters.py:97 | FL starting
# INFO:flwr:FL starting
# INFO flwr 2025-02-21 18:51:23,086 | strategy.py:120 | Configure fit: stage 0, 0, True
# INFO:flwr:Configure fit: stage 0, 0, True
# INFO flwr 2025-02-21 18:51:23,088 | strategy.py:126 | Stage 0
# INFO:flwr:Stage 0
# DEBUG flwr 2025-02-21 18:51:23,093 | server_returns_parameters.py:223 | fit_round 1: strategy sampled 20 clients (out of 3290)
# DEBUG:flwr:fit_round 1: strategy sampled 20 clients (out of 3290)
# INFO flwr 2025-02-21 18:51:23,096 | client.py:181 | Client 0: starting stage 0...
# INFO:flwr:Client 0: starting stage 0...
# INFO flwr 2025-02-21 18:51:23,098 | client.py:181 | Client 1: starting stage 0...
# INFO:flwr:Client 1: starting stage 0...
# INFO flwr 2025-02-21 18:51:23,100 | client.py:181 | Client 2: starting stage 0...
# INFO:flwr:Client 2: starting stage 0...
# INFO flwr 2025-02-21 18:51:23,105 | client.py:209 | Client 1: stage 0 completes. uploading public keys...
# INFO:flwr:Client 1: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:23,118 | client.py:181 | Client 6: starting stage 0...
# INFO:flwr:Client 6: starting stage 0...
# INFO flwr 2025-02-21 18:51:23,105 | client.py:209 | Client 0: stage 0 completes. uploading public keys...
# INFO:flwr:Client 0: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:23,107 | client.py:181 | Client 4: starting stage 0...
# INFO:flwr:Client 4: starting stage 0...
# INFO flwr 2025-02-21 18:51:23,108 | client.py:181 | Client 5: starting stage 0...
# INFO:flwr:Client 5: starting stage 0...
# INFO flwr 2025-02-21 18:51:23,105 | client.py:181 | Client 3: starting stage 0...
# INFO flwr 2025-02-21 18:51:23,124 | client.py:209 | Client 2: stage 0 completes. uploading public keys...
# INFO:flwr:Client 3: starting stage 0...
# INFO flwr 2025-02-21 18:51:23,131 | client.py:209 | Client 4: stage 0 completes. uploading public keys...
# INFO:flwr:Client 2: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:23,133 | client.py:181 | Client 7: starting stage 0...
# INFO:flwr:Client 4: stage 0 completes. uploading public keys...
# INFO:flwr:Client 7: starting stage 0...
# INFO flwr 2025-02-21 18:51:23,151 | client.py:181 | Client 9: starting stage 0...
# INFO:flwr:Client 9: starting stage 0...
# INFO flwr 2025-02-21 18:51:23,147 | client.py:181 | Client 8: starting stage 0...
# INFO:flwr:Client 8: starting stage 0...
# INFO flwr 2025-02-21 18:51:23,136 | client.py:209 | Client 6: stage 0 completes. uploading public keys...
# INFO:flwr:Client 6: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:23,153 | client.py:209 | Client 5: stage 0 completes. uploading public keys...
# INFO:flwr:Client 5: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:23,155 | client.py:209 | Client 3: stage 0 completes. uploading public keys...
# INFO:flwr:Client 3: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:23,160 | client.py:209 | Client 7: stage 0 completes. uploading public keys...
# INFO:flwr:Client 7: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:23,168 | client.py:209 | Client 8: stage 0 completes. uploading public keys...
# INFO:flwr:Client 8: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:23,178 | client.py:181 | Client 13: starting stage 0...
# INFO:flwr:Client 13: starting stage 0...
# INFO flwr 2025-02-21 18:51:23,172 | client.py:181 | Client 11: starting stage 0...
# INFO:flwr:Client 11: starting stage 0...
# INFO flwr 2025-02-21 18:51:23,174 | client.py:181 | Client 12: starting stage 0...
# INFO:flwr:Client 12: starting stage 0...
# INFO flwr 2025-02-21 18:51:23,178 | client.py:209 | Client 9: stage 0 completes. uploading public keys...
# INFO:flwr:Client 9: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:23,170 | client.py:181 | Client 10: starting stage 0...
# INFO flwr 2025-02-21 18:51:23,193 | client.py:209 | Client 12: stage 0 completes. uploading public keys...
# INFO:flwr:Client 10: starting stage 0...
# INFO:flwr:Client 12: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:23,189 | client.py:209 | Client 11: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:23,190 | client.py:209 | Client 13: stage 0 completes. uploading public keys...
# INFO:flwr:Client 13: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:23,204 | client.py:181 | Client 17: starting stage 0...
# INFO flwr 2025-02-21 18:51:23,197 | client.py:181 | Client 15: starting stage 0...
# INFO:flwr:Client 11: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:23,199 | client.py:209 | Client 10: stage 0 completes. uploading public keys...
# INFO:flwr:Client 17: starting stage 0...
# INFO:flwr:Client 15: starting stage 0...
# INFO:flwr:Client 10: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:23,202 | client.py:181 | Client 16: starting stage 0...
# INFO:flwr:Client 16: starting stage 0...
# INFO flwr 2025-02-21 18:51:23,187 | client.py:181 | Client 14: starting stage 0...
# INFO flwr 2025-02-21 18:51:23,210 | client.py:181 | Client 18: starting stage 0...
# INFO:flwr:Client 14: starting stage 0...
# INFO:flwr:Client 18: starting stage 0...
# INFO flwr 2025-02-21 18:51:23,220 | client.py:209 | Client 15: stage 0 completes. uploading public keys...
# INFO:flwr:Client 15: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:23,224 | client.py:181 | Client 19: starting stage 0...
# INFO flwr 2025-02-21 18:51:23,224 | client.py:209 | Client 17: stage 0 completes. uploading public keys...
# INFO:flwr:Client 19: starting stage 0...
# INFO:flwr:Client 17: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:23,243 | client.py:209 | Client 16: stage 0 completes. uploading public keys...
# INFO:flwr:Client 16: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:23,243 | client.py:209 | Client 14: stage 0 completes. uploading public keys...
# INFO:flwr:Client 14: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:23,244 | client.py:209 | Client 18: stage 0 completes. uploading public keys...
# INFO:flwr:Client 18: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:51:23,255 | client.py:209 | Client 19: stage 0 completes. uploading public keys...
# INFO:flwr:Client 19: stage 0 completes. uploading public keys...
# DEBUG flwr 2025-02-21 18:51:23,277 | server_returns_parameters.py:237 | fit_round 1 received 20 results and 0 failures
# DEBUG:flwr:fit_round 1 received 20 results and 0 failures
# INFO flwr 2025-02-21 18:51:23,279 | strategy.py:186 | Length of content is 450
# INFO:flwr:Length of content is 450
# INFO flwr 2025-02-21 18:51:23,281 | server_returns_parameters.py:171 | evaluate_round 1: no clients selected, cancel
# INFO:flwr:evaluate_round 1: no clients selected, cancel
# INFO flwr 2025-02-21 18:51:23,282 | strategy.py:120 | Configure fit: stage 1, 0, False
# INFO:flwr:Configure fit: stage 1, 0, False
# DEBUG flwr 2025-02-21 18:51:23,284 | server_returns_parameters.py:223 | fit_round 2: strategy sampled 20 clients (out of 3290)
# DEBUG:flwr:fit_round 2: strategy sampled 20 clients (out of 3290)
# INFO flwr 2025-02-21 18:51:23,286 | client.py:146 | CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO:flwr:CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO flwr 2025-02-21 18:51:23,290 | client.py:221 | Client 1: starting stage 1...
# INFO:flwr:Client 1: starting stage 1...
# INFO flwr 2025-02-21 18:51:23,295 | client.py:146 | CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO:flwr:CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO flwr 2025-02-21 18:51:23,300 | client.py:221 | Client 2: starting stage 1...
# INFO:flwr:Client 2: starting stage 1...
# INFO flwr 2025-02-21 18:51:23,302 | client.py:146 | CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO:flwr:CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO flwr 2025-02-21 18:51:23,304 | client.py:221 | Client 9: starting stage 1...
# INFO:flwr:Client 9: starting stage 1...
# INFO flwr 2025-02-21 18:51:23,305 | client.py:146 | CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO:flwr:CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO flwr 2025-02-21 18:51:23,309 | client.py:221 | Client 6: starting stage 1...
# INFO:flwr:Client 6: starting stage 1...
# INFO flwr 2025-02-21 18:51:23,311 | client.py:146 | CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO:flwr:CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO flwr 2025-02-21 18:51:23,312 | client.py:146 | CID 839 reloading from /content/secagg/client_data/839.pth
# INFO:flwr:CID 839 reloading from /content/secagg/client_data/839.pth
# INFO flwr 2025-02-21 18:51:23,328 | client.py:221 | Client 4: starting stage 1...
# INFO:flwr:Client 4: starting stage 1...
# INFO flwr 2025-02-21 18:51:23,331 | client.py:221 | Client 17: starting stage 1...
# INFO:flwr:Client 17: starting stage 1...
# INFO flwr 2025-02-21 18:51:23,554 | client.py:287 | Client 1: stage 1 completes. uploading key shares...
# INFO:flwr:Client 1: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:51:23,574 | client.py:146 | CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO:flwr:CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO flwr 2025-02-21 18:51:23,596 | client.py:221 | Client 14: starting stage 1...
# INFO:flwr:Client 14: starting stage 1...
# INFO flwr 2025-02-21 18:51:23,655 | client.py:287 | Client 6: stage 1 completes. uploading key shares...
# INFO:flwr:Client 6: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:51:23,672 | client.py:146 | CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO:flwr:CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO flwr 2025-02-21 18:51:23,679 | client.py:221 | Client 8: starting stage 1...
# INFO:flwr:Client 8: starting stage 1...
# INFO flwr 2025-02-21 18:51:23,680 | client.py:287 | Client 9: stage 1 completes. uploading key shares...
# INFO:flwr:Client 9: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:51:23,700 | client.py:146 | CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO:flwr:CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO flwr 2025-02-21 18:51:23,710 | client.py:221 | Client 10: starting stage 1...
# INFO:flwr:Client 10: starting stage 1...
# INFO flwr 2025-02-21 18:51:23,748 | client.py:287 | Client 17: stage 1 completes. uploading key shares...
# INFO:flwr:Client 17: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:51:23,757 | client.py:146 | CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO:flwr:CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO flwr 2025-02-21 18:51:23,765 | client.py:287 | Client 2: stage 1 completes. uploading key shares...
# INFO:flwr:Client 2: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:51:23,783 | client.py:146 | CID 678 reloading from /content/secagg/client_data/678.pth
# INFO:flwr:CID 678 reloading from /content/secagg/client_data/678.pth
# INFO flwr 2025-02-21 18:51:23,788 | client.py:221 | Client 7: starting stage 1...
# INFO:flwr:Client 7: starting stage 1...
# INFO flwr 2025-02-21 18:51:23,790 | client.py:221 | Client 19: starting stage 1...
# INFO:flwr:Client 19: starting stage 1...
# INFO flwr 2025-02-21 18:51:23,814 | client.py:287 | Client 4: stage 1 completes. uploading key shares...
# INFO:flwr:Client 4: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:51:23,829 | client.py:146 | CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO:flwr:CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO flwr 2025-02-21 18:51:23,848 | client.py:221 | Client 12: starting stage 1...
# INFO:flwr:Client 12: starting stage 1...
# INFO flwr 2025-02-21 18:51:23,912 | client.py:287 | Client 14: stage 1 completes. uploading key shares...
# INFO:flwr:Client 14: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:51:23,946 | client.py:146 | CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO:flwr:CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO flwr 2025-02-21 18:51:23,968 | client.py:221 | Client 18: starting stage 1...
# INFO:flwr:Client 18: starting stage 1...
# INFO flwr 2025-02-21 18:51:24,014 | client.py:287 | Client 10: stage 1 completes. uploading key shares...
# INFO:flwr:Client 10: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:51:24,021 | client.py:287 | Client 8: stage 1 completes. uploading key shares...
# INFO:flwr:Client 8: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:51:24,042 | client.py:146 | CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO:flwr:CID 1603 reloading from /content/secagg/client_data/1603.pth
# ...
# INFO flwr 2025-02-21 18:52:02,352 | client.py:146 | CID 3068 reloading from /content/secagg/client_data/3068.pth
# INFO:flwr:CID 3168 reloading from /content/secagg/client_data/3168.pth
# INFO:flwr:CID 3068 reloading from /content/secagg/client_data/3068.pth
# INFO flwr 2025-02-21 18:52:02,364 | client.py:295 | Client 35: starting stage 2...
# INFO:flwr:Client 35: starting stage 2...
# INFO flwr 2025-02-21 18:52:02,360 | client.py:295 | Client 19: starting stage 2...
# INFO:flwr:Client 19: starting stage 2...
# INFO flwr 2025-02-21 18:52:02,376 | client.py:295 | Client 13: starting stage 2...
# INFO:flwr:Client 13: starting stage 2...
# INFO flwr 2025-02-21 18:52:02,403 | client.py:146 | CID 807 reloading from /content/secagg/client_data/807.pth
# INFO:flwr:CID 807 reloading from /content/secagg/client_data/807.pth
# INFO flwr 2025-02-21 18:52:02,393 | client.py:146 | CID 1287 reloading from /content/secagg/client_data/1287.pth
# INFO flwr 2025-02-21 18:52:02,424 | client.py:295 | Client 30: starting stage 2...
# INFO:flwr:CID 1287 reloading from /content/secagg/client_data/1287.pth
# INFO:flwr:Client 30: starting stage 2...
# INFO flwr 2025-02-21 18:52:02,429 | client.py:295 | Client 38: starting stage 2...
# INFO:flwr:Client 38: starting stage 2...
# INFO flwr 2025-02-21 18:52:02,453 | client.py:146 | CID 2767 reloading from /content/secagg/client_data/2767.pth
# INFO:flwr:CID 2767 reloading from /content/secagg/client_data/2767.pth
# INFO flwr 2025-02-21 18:52:02,480 | client.py:295 | Client 26: starting stage 2...
# INFO:flwr:Client 26: starting stage 2...
# INFO flwr 2025-02-21 18:52:02,523 | client.py:146 | CID 823 reloading from /content/secagg/client_data/823.pth
# INFO:flwr:CID 823 reloading from /content/secagg/client_data/823.pth
# INFO flwr 2025-02-21 18:52:02,533 | client.py:295 | Client 12: starting stage 2...
# INFO:flwr:Client 12: starting stage 2...
# INFO flwr 2025-02-21 18:52:02,551 | client.py:146 | CID 428 reloading from /content/secagg/client_data/428.pth
# INFO:flwr:CID 428 reloading from /content/secagg/client_data/428.pth
# INFO flwr 2025-02-21 18:52:02,576 | client.py:295 | Client 31: starting stage 2...
# INFO:flwr:Client 31: starting stage 2...
# INFO flwr 2025-02-21 18:52:02,583 | client.py:146 | CID 1887 reloading from /content/secagg/client_data/1887.pth
# INFO:flwr:CID 1887 reloading from /content/secagg/client_data/1887.pth
# INFO flwr 2025-02-21 18:52:02,610 | client.py:295 | Client 1: starting stage 2...
# INFO:flwr:Client 1: starting stage 2...
# INFO flwr 2025-02-21 18:52:02,641 | client.py:146 | CID 485 reloading from /content/secagg/client_data/485.pth
# INFO:flwr:CID 485 reloading from /content/secagg/client_data/485.pth
# INFO flwr 2025-02-21 18:52:02,659 | client.py:295 | Client 0: starting stage 2...
# INFO:flwr:Client 0: starting stage 2...
# INFO flwr 2025-02-21 18:52:02,683 | client.py:146 | CID 220 reloading from /content/secagg/client_data/220.pth
# INFO:flwr:CID 220 reloading from /content/secagg/client_data/220.pth
# INFO flwr 2025-02-21 18:52:02,699 | client.py:295 | Client 25: starting stage 2...
# INFO:flwr:Client 25: starting stage 2...
# INFO flwr 2025-02-21 18:52:02,720 | client.py:146 | CID 275 reloading from /content/secagg/client_data/275.pth
# INFO:flwr:CID 275 reloading from /content/secagg/client_data/275.pth
# INFO flwr 2025-02-21 18:52:02,745 | client.py:295 | Client 14: starting stage 2...
# INFO:flwr:Client 14: starting stage 2...
# INFO flwr 2025-02-21 18:52:02,780 | client.py:146 | CID 1084 reloading from /content/secagg/client_data/1084.pth
# INFO:flwr:CID 1084 reloading from /content/secagg/client_data/1084.pth
# INFO flwr 2025-02-21 18:52:02,800 | client.py:295 | Client 11: starting stage 2...
# INFO:flwr:Client 11: starting stage 2...
# INFO flwr 2025-02-21 18:52:02,826 | client.py:146 | CID 2152 reloading from /content/secagg/client_data/2152.pth
# INFO:flwr:CID 2152 reloading from /content/secagg/client_data/2152.pth
# INFO flwr 2025-02-21 18:52:02,838 | client.py:397 | Client 37: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 37: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:52:02,850 | client.py:295 | Client 16: starting stage 2...
# INFO:flwr:Client 16: starting stage 2...
# INFO flwr 2025-02-21 18:52:02,862 | client.py:146 | CID 806 reloading from /content/secagg/client_data/806.pth
# INFO:flwr:CID 806 reloading from /content/secagg/client_data/806.pth
# INFO flwr 2025-02-21 18:52:02,867 | client.py:397 | Client 36: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:52:02,870 | client.py:146 | CID 805 reloading from /content/secagg/client_data/805.pth
# INFO:flwr:Client 36: stage 2 completes. uploading masked weights...
# INFO:flwr:CID 805 reloading from /content/secagg/client_data/805.pth
# INFO flwr 2025-02-21 18:52:02,885 | client.py:295 | Client 33: starting stage 2...
# INFO:flwr:Client 33: starting stage 2...
# INFO flwr 2025-02-21 18:52:02,887 | client.py:146 | CID 2534 reloading from /content/secagg/client_data/2534.pth
# INFO flwr 2025-02-21 18:52:02,888 | client.py:295 | Client 29: starting stage 2...
# INFO:flwr:CID 2534 reloading from /content/secagg/client_data/2534.pth
# INFO:flwr:Client 29: starting stage 2...
# INFO flwr 2025-02-21 18:52:02,898 | client.py:295 | Client 17: starting stage 2...
# INFO:flwr:Client 17: starting stage 2...
# INFO flwr 2025-02-21 18:52:02,912 | client.py:146 | CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO:flwr:CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO flwr 2025-02-21 18:52:02,926 | client.py:295 | Client 28: starting stage 2...
# INFO:flwr:Client 28: starting stage 2...
# INFO flwr 2025-02-21 18:52:02,913 | client.py:146 | CID 2614 reloading from /content/secagg/client_data/2614.pth
# INFO flwr 2025-02-21 18:52:02,933 | client.py:146 | CID 179 reloading from /content/secagg/client_data/179.pth
# INFO:flwr:CID 2614 reloading from /content/secagg/client_data/2614.pth
# INFO:flwr:CID 179 reloading from /content/secagg/client_data/179.pth
# INFO flwr 2025-02-21 18:52:02,945 | client.py:295 | Client 15: starting stage 2...
# INFO:flwr:Client 15: starting stage 2...
# INFO flwr 2025-02-21 18:52:02,947 | client.py:295 | Client 20: starting stage 2...
# INFO:flwr:Client 20: starting stage 2...
# INFO flwr 2025-02-21 18:52:02,970 | client.py:146 | CID 701 reloading from /content/secagg/client_data/701.pth
# INFO:flwr:CID 701 reloading from /content/secagg/client_data/701.pth
# INFO flwr 2025-02-21 18:52:02,971 | client.py:146 | CID 2538 reloading from /content/secagg/client_data/2538.pth
# INFO:flwr:CID 2538 reloading from /content/secagg/client_data/2538.pth
# INFO flwr 2025-02-21 18:52:02,975 | client.py:146 | CID 1872 reloading from /content/secagg/client_data/1872.pth
# INFO flwr 2025-02-21 18:52:02,982 | client.py:397 | Client 39: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 39: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:52:02,990 | client.py:146 | CID 70 reloading from /content/secagg/client_data/70.pth
# INFO:flwr:CID 1872 reloading from /content/secagg/client_data/1872.pth
# INFO:flwr:CID 70 reloading from /content/secagg/client_data/70.pth
# INFO flwr 2025-02-21 18:52:02,999 | client.py:295 | Client 27: starting stage 2...
# INFO:flwr:Client 27: starting stage 2...
# INFO flwr 2025-02-21 18:52:02,994 | client.py:295 | Client 9: starting stage 2...
# INFO flwr 2025-02-21 18:52:02,997 | client.py:295 | Client 24: starting stage 2...
# INFO flwr 2025-02-21 18:52:02,985 | client.py:295 | Client 3: starting stage 2...
# INFO:flwr:Client 9: starting stage 2...
# INFO:flwr:Client 24: starting stage 2...
# INFO:flwr:Client 3: starting stage 2...
# INFO flwr 2025-02-21 18:52:03,021 | client.py:146 | CID 1009 reloading from /content/secagg/client_data/1009.pth
# INFO:flwr:CID 1009 reloading from /content/secagg/client_data/1009.pth
# INFO flwr 2025-02-21 18:52:03,024 | client.py:146 | CID 2364 reloading from /content/secagg/client_data/2364.pth
# INFO:flwr:CID 2364 reloading from /content/secagg/client_data/2364.pth
# INFO flwr 2025-02-21 18:52:03,036 | client.py:295 | Client 18: starting stage 2...
# INFO:flwr:Client 18: starting stage 2...
# INFO flwr 2025-02-21 18:52:03,042 | client.py:295 | Client 2: starting stage 2...
# INFO:flwr:Client 2: starting stage 2...
# INFO flwr 2025-02-21 18:52:03,062 | client.py:397 | Client 35: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 35: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:52:03,065 | client.py:397 | Client 38: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 38: stage 2 completes. uploading masked weights...
# DEBUG flwr 2025-02-21 18:52:03,079 | server_returns_parameters.py:237 | fit_round 7 received 5 results and 35 failures
# DEBUG:flwr:fit_round 7 received 5 results and 35 failures
# INFO flwr 2025-02-21 18:52:03,082 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,083 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,086 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,089 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,091 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,094 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,095 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,097 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,098 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,100 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,101 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,102 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,103 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,105 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,106 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,108 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,109 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,111 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,112 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,114 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,115 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,117 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,118 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,120 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,121 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,123 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,124 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,125 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,127 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,129 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,130 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,131 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,133 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,134 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,135 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:03,136 | strategy.py:186 | Length of content is 4
# INFO:flwr:Length of content is 4
# INFO flwr 2025-02-21 18:52:03,138 | server_returns_parameters.py:171 | evaluate_round 7: no clients selected, cancel
# INFO:flwr:evaluate_round 7: no clients selected, cancel
# INFO flwr 2025-02-21 18:52:03,144 | strategy.py:120 | Configure fit: stage 3, 0, False
# INFO:flwr:Configure fit: stage 3, 0, False
# DEBUG flwr 2025-02-21 18:52:03,146 | server_returns_parameters.py:223 | fit_round 8: strategy sampled 5 clients (out of 3290)
# DEBUG:flwr:fit_round 8: strategy sampled 5 clients (out of 3290)
# INFO flwr 2025-02-21 18:52:03,155 | client.py:146 | CID 3269 reloading from /content/secagg/client_data/3269.pth
# INFO:flwr:CID 3269 reloading from /content/secagg/client_data/3269.pth
# INFO flwr 2025-02-21 18:52:03,156 | client.py:146 | CID 3068 reloading from /content/secagg/client_data/3068.pth
# INFO:flwr:CID 3068 reloading from /content/secagg/client_data/3068.pth
# INFO flwr 2025-02-21 18:52:03,161 | client.py:146 | CID 1287 reloading from /content/secagg/client_data/1287.pth
# INFO:flwr:CID 1287 reloading from /content/secagg/client_data/1287.pth
# INFO flwr 2025-02-21 18:52:03,165 | client.py:146 | CID 51 reloading from /content/secagg/client_data/51.pth
# INFO:flwr:CID 51 reloading from /content/secagg/client_data/51.pth
# INFO flwr 2025-02-21 18:52:03,166 | client.py:146 | CID 2329 reloading from /content/secagg/client_data/2329.pth
# INFO:flwr:CID 2329 reloading from /content/secagg/client_data/2329.pth
# DEBUG flwr 2025-02-21 18:52:03,200 | server_returns_parameters.py:237 | fit_round 8 received 5 results and 0 failures
# DEBUG:flwr:fit_round 8 received 5 results and 0 failures
# INFO flwr 2025-02-21 18:52:03,202 | strategy.py:186 | Length of content is 17406
# INFO:flwr:Length of content is 17406
# INFO flwr 2025-02-21 18:52:07,410 | server_returns_parameters.py:171 | evaluate_round 8: no clients selected, cancel
# INFO:flwr:evaluate_round 8: no clients selected, cancel
# INFO flwr 2025-02-21 18:52:07,411 | server_returns_parameters.py:150 | FL finished in 24.14565562300004
# INFO:flwr:FL finished in 24.14565562300004
# INFO flwr 2025-02-21 18:52:07,413 | app.py:250 | app_fit: losses_distributed []
# INFO:flwr:app_fit: losses_distributed []
# INFO flwr 2025-02-21 18:52:07,416 | app.py:251 | app_fit: metrics_distributed_fit {'total_cost': [(1, 18000), (2, 1360640), (3, 401340), (4, 87030), (5, 18000), (6, 1360640), (7, 401340), (8, 87030)]}
# INFO:flwr:app_fit: metrics_distributed_fit {'total_cost': [(1, 18000), (2, 1360640), (3, 401340), (4, 87030), (5, 18000), (6, 1360640), (7, 401340), (8, 87030)]}
# INFO flwr 2025-02-21 18:52:07,417 | app.py:252 | app_fit: metrics_distributed {}
# INFO:flwr:app_fit: metrics_distributed {}
# INFO flwr 2025-02-21 18:52:07,418 | app.py:253 | app_fit: losses_centralized []
# INFO:flwr:app_fit: losses_centralized []
# INFO flwr 2025-02-21 18:52:07,419 | app.py:254 | app_fit: metrics_centralized {}
# INFO:flwr:app_fit: metrics_centralized {}

# %%
total_cost_list = []

for num_clients_per_round in num_clients_per_round_list:
    total_costs = results[num_clients_per_round][1].metrics_distributed_fit['total_cost']
    total_cost = sum(cost for _, cost in total_costs)
    total_cost_list.append(total_cost)

# %%
plt.figure(figsize=(8,6))
plt.scatter(num_clients_per_round_list, total_cost_list)
plt.xlabel("Number of Clients per Round")
plt.ylabel("Total Communication Cost")
plt.title("Impact of Clients per Round on Communication Cost")
plt.grid(True)
plt.show()

# %%
num_model_parameters_list = [2**i for i in range(10, 16)]

results_params = {num_params: [] for num_params in num_model_parameters_list}

for num_params in num_model_parameters_list:
    params, hist = run_sec_agg_demo(n_model_parameters=num_params)

    results_params[num_params] = [params, hist]
# Out:
# INFO flwr 2025-02-21 18:52:08,154 | app.py:149 | Starting Flower simulation, config: ServerConfig(num_rounds=8, round_timeout=None)
# INFO:flwr:Starting Flower simulation, config: ServerConfig(num_rounds=8, round_timeout=None)
# INFO flwr 2025-02-21 18:52:08,170 | server_returns_parameters.py:81 | Initializing global parameters
# INFO:flwr:Initializing global parameters
# INFO flwr 2025-02-21 18:52:08,174 | server_returns_parameters.py:273 | Using initial parameters provided by strategy
# INFO:flwr:Using initial parameters provided by strategy
# INFO flwr 2025-02-21 18:52:08,177 | server_returns_parameters.py:84 | Evaluating initial parameters
# INFO:flwr:Evaluating initial parameters
# INFO flwr 2025-02-21 18:52:08,180 | server_returns_parameters.py:97 | FL starting
# INFO:flwr:FL starting
# INFO flwr 2025-02-21 18:52:08,182 | strategy.py:120 | Configure fit: stage 0, 0, True
# INFO:flwr:Configure fit: stage 0, 0, True
# INFO flwr 2025-02-21 18:52:08,183 | strategy.py:126 | Stage 0
# INFO:flwr:Stage 0
# DEBUG flwr 2025-02-21 18:52:08,186 | server_returns_parameters.py:223 | fit_round 1: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 1: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-21 18:52:08,189 | client.py:181 | Client 0: starting stage 0...
# INFO:flwr:Client 0: starting stage 0...
# INFO flwr 2025-02-21 18:52:08,189 | client.py:181 | Client 1: starting stage 0...
# INFO flwr 2025-02-21 18:52:08,191 | client.py:181 | Client 2: starting stage 0...
# INFO:flwr:Client 1: starting stage 0...
# INFO:flwr:Client 2: starting stage 0...
# INFO flwr 2025-02-21 18:52:08,196 | client.py:181 | Client 5: starting stage 0...
# INFO:flwr:Client 5: starting stage 0...
# INFO flwr 2025-02-21 18:52:08,199 | client.py:181 | Client 4: starting stage 0...
# INFO:flwr:Client 4: starting stage 0...
# INFO flwr 2025-02-21 18:52:08,200 | client.py:209 | Client 1: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:08,196 | client.py:181 | Client 3: starting stage 0...
# INFO flwr 2025-02-21 18:52:08,205 | client.py:209 | Client 0: stage 0 completes. uploading public keys...
# INFO:flwr:Client 1: stage 0 completes. uploading public keys...
# INFO:flwr:Client 3: starting stage 0...
# INFO:flwr:Client 0: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:08,211 | client.py:181 | Client 6: starting stage 0...
# INFO flwr 2025-02-21 18:52:08,212 | client.py:209 | Client 5: stage 0 completes. uploading public keys...
# INFO:flwr:Client 6: starting stage 0...
# INFO:flwr:Client 5: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:08,213 | client.py:209 | Client 2: stage 0 completes. uploading public keys...
# INFO:flwr:Client 2: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:08,214 | client.py:209 | Client 4: stage 0 completes. uploading public keys...
# INFO:flwr:Client 4: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:08,218 | client.py:181 | Client 7: starting stage 0...
# INFO:flwr:Client 7: starting stage 0...
# INFO flwr 2025-02-21 18:52:08,224 | client.py:181 | Client 8: starting stage 0...
# INFO:flwr:Client 8: starting stage 0...
# INFO flwr 2025-02-21 18:52:08,227 | client.py:209 | Client 3: stage 0 completes. uploading public keys...
# INFO:flwr:Client 3: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:08,228 | client.py:209 | Client 6: stage 0 completes. uploading public keys...
# INFO:flwr:Client 6: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:08,229 | client.py:181 | Client 9: starting stage 0...
# INFO:flwr:Client 9: starting stage 0...
# INFO flwr 2025-02-21 18:52:08,232 | client.py:209 | Client 7: stage 0 completes. uploading public keys...
# INFO:flwr:Client 7: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:08,237 | client.py:209 | Client 8: stage 0 completes. uploading public keys...
# INFO:flwr:Client 8: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:08,247 | client.py:209 | Client 9: stage 0 completes. uploading public keys...
# INFO:flwr:Client 9: stage 0 completes. uploading public keys...
# DEBUG flwr 2025-02-21 18:52:08,264 | server_returns_parameters.py:237 | fit_round 1 received 10 results and 0 failures
# DEBUG:flwr:fit_round 1 received 10 results and 0 failures
# INFO flwr 2025-02-21 18:52:08,267 | strategy.py:186 | Length of content is 450
# INFO:flwr:Length of content is 450
# INFO flwr 2025-02-21 18:52:08,270 | server_returns_parameters.py:171 | evaluate_round 1: no clients selected, cancel
# INFO:flwr:evaluate_round 1: no clients selected, cancel
# INFO flwr 2025-02-21 18:52:08,273 | strategy.py:120 | Configure fit: stage 1, 0, False
# INFO:flwr:Configure fit: stage 1, 0, False
# DEBUG flwr 2025-02-21 18:52:08,276 | server_returns_parameters.py:223 | fit_round 2: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 2: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-21 18:52:08,279 | client.py:146 | CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO:flwr:CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO flwr 2025-02-21 18:52:08,280 | client.py:146 | CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO flwr 2025-02-21 18:52:08,284 | client.py:221 | Client 1: starting stage 1...
# INFO:flwr:CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO:flwr:Client 1: starting stage 1...
# INFO flwr 2025-02-21 18:52:08,285 | client.py:146 | CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO:flwr:CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO flwr 2025-02-21 18:52:08,289 | client.py:221 | Client 0: starting stage 1...
# INFO:flwr:Client 0: starting stage 1...
# INFO flwr 2025-02-21 18:52:08,294 | client.py:146 | CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO flwr 2025-02-21 18:52:08,294 | client.py:221 | Client 8: starting stage 1...
# INFO flwr 2025-02-21 18:52:08,295 | client.py:146 | CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO:flwr:CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO flwr 2025-02-21 18:52:08,295 | client.py:146 | CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO:flwr:Client 8: starting stage 1...
# INFO:flwr:CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO flwr 2025-02-21 18:52:08,302 | client.py:221 | Client 4: starting stage 1...
# INFO:flwr:CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO flwr 2025-02-21 18:52:08,307 | client.py:221 | Client 9: starting stage 1...
# INFO:flwr:Client 4: starting stage 1...
# INFO:flwr:Client 9: starting stage 1...
# INFO flwr 2025-02-21 18:52:08,319 | client.py:221 | Client 3: starting stage 1...
# INFO:flwr:Client 3: starting stage 1...
# INFO flwr 2025-02-21 18:52:08,413 | client.py:287 | Client 4: stage 1 completes. uploading key shares...
# INFO:flwr:Client 4: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:08,432 | client.py:287 | Client 8: stage 1 completes. uploading key shares...
# INFO:flwr:Client 8: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:08,433 | client.py:287 | Client 9: stage 1 completes. uploading key shares...
# INFO:flwr:Client 9: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:08,445 | client.py:287 | Client 0: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:08,439 | client.py:146 | CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO:flwr:Client 0: stage 1 completes. uploading key shares...
# INFO:flwr:CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO flwr 2025-02-21 18:52:08,455 | client.py:146 | CID 678 reloading from /content/secagg/client_data/678.pth
# INFO:flwr:CID 678 reloading from /content/secagg/client_data/678.pth
# INFO flwr 2025-02-21 18:52:08,456 | client.py:146 | CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO:flwr:CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO flwr 2025-02-21 18:52:08,457 | client.py:146 | CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO:flwr:CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO flwr 2025-02-21 18:52:08,462 | client.py:221 | Client 6: starting stage 1...
# INFO:flwr:Client 6: starting stage 1...
# INFO flwr 2025-02-21 18:52:08,474 | client.py:221 | Client 7: starting stage 1...
# INFO:flwr:Client 7: starting stage 1...
# INFO flwr 2025-02-21 18:52:08,475 | client.py:221 | Client 2: starting stage 1...
# INFO flwr 2025-02-21 18:52:08,482 | client.py:221 | Client 5: starting stage 1...
# INFO:flwr:Client 2: starting stage 1...
# INFO:flwr:Client 5: starting stage 1...
# INFO flwr 2025-02-21 18:52:08,492 | client.py:287 | Client 1: stage 1 completes. uploading key shares...
# INFO:flwr:Client 1: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:08,516 | client.py:287 | Client 3: stage 1 completes. uploading key shares...
# INFO:flwr:Client 3: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:08,601 | client.py:287 | Client 2: stage 1 completes. uploading key shares...
# INFO:flwr:Client 2: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:08,611 | client.py:287 | Client 5: stage 1 completes. uploading key shares...
# INFO:flwr:Client 5: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:08,622 | client.py:287 | Client 6: stage 1 completes. uploading key shares...
# INFO:flwr:Client 6: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:08,636 | client.py:287 | Client 7: stage 1 completes. uploading key shares...
# INFO:flwr:Client 7: stage 1 completes. uploading key shares...
# DEBUG flwr 2025-02-21 18:52:08,644 | server_returns_parameters.py:237 | fit_round 2 received 10 results and 0 failures
# DEBUG:flwr:fit_round 2 received 10 results and 0 failures
# INFO flwr 2025-02-21 18:52:08,646 | strategy.py:186 | Length of content is 7916
# INFO:flwr:Length of content is 7916
# INFO flwr 2025-02-21 18:52:08,649 | server_returns_parameters.py:171 | evaluate_round 2: no clients selected, cancel
# INFO:flwr:evaluate_round 2: no clients selected, cancel
# INFO flwr 2025-02-21 18:52:08,650 | strategy.py:120 | Configure fit: stage 2, 0, False
# INFO:flwr:Configure fit: stage 2, 0, False
# DEBUG flwr 2025-02-21 18:52:08,653 | server_returns_parameters.py:223 | fit_round 3: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 3: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-21 18:52:08,658 | client.py:146 | CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO:flwr:CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO flwr 2025-02-21 18:52:08,661 | client.py:146 | CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO:flwr:CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO flwr 2025-02-21 18:52:08,663 | client.py:146 | CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO:flwr:CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO flwr 2025-02-21 18:52:08,665 | client.py:146 | CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO:flwr:CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO flwr 2025-02-21 18:52:08,668 | client.py:146 | CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO:flwr:CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO flwr 2025-02-21 18:52:08,670 | client.py:295 | Client 5: starting stage 2...
# INFO:flwr:Client 5: starting stage 2...
# INFO flwr 2025-02-21 18:52:08,671 | client.py:146 | CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO:flwr:CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO flwr 2025-02-21 18:52:08,674 | client.py:295 | Client 3: starting stage 2...
# INFO flwr 2025-02-21 18:52:08,678 | client.py:295 | Client 0: starting stage 2...
# INFO:flwr:Client 3: starting stage 2...
# INFO:flwr:Client 0: starting stage 2...
# INFO flwr 2025-02-21 18:52:08,681 | client.py:295 | Client 2: starting stage 2...
# INFO:flwr:Client 2: starting stage 2...
# INFO flwr 2025-02-21 18:52:08,696 | client.py:146 | CID 678 reloading from /content/secagg/client_data/678.pth
# INFO flwr 2025-02-21 18:52:08,698 | client.py:146 | CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO:flwr:CID 678 reloading from /content/secagg/client_data/678.pth
# INFO flwr 2025-02-21 18:52:08,701 | client.py:146 | CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO:flwr:CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO flwr 2025-02-21 18:52:08,703 | client.py:295 | Client 6: starting stage 2...
# INFO:flwr:CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO flwr 2025-02-21 18:52:08,703 | client.py:295 | Client 1: starting stage 2...
# INFO:flwr:Client 6: starting stage 2...
# INFO flwr 2025-02-21 18:52:08,708 | client.py:295 | Client 7: starting stage 2...
# INFO:flwr:Client 1: starting stage 2...
# INFO flwr 2025-02-21 18:52:08,708 | client.py:295 | Client 4: starting stage 2...
# INFO:flwr:Client 7: starting stage 2...
# INFO flwr 2025-02-21 18:52:08,725 | client.py:146 | CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO:flwr:Client 4: starting stage 2...
# INFO flwr 2025-02-21 18:52:08,719 | client.py:295 | Client 8: starting stage 2...
# INFO:flwr:CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO:flwr:Client 8: starting stage 2...
# INFO flwr 2025-02-21 18:52:08,738 | client.py:295 | Client 9: starting stage 2...
# INFO:flwr:Client 9: starting stage 2...
# INFO flwr 2025-02-21 18:52:08,771 | client.py:397 | Client 8: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 8: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:52:08,782 | client.py:397 | Client 5: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 5: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:52:08,796 | client.py:397 | Client 7: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 7: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:52:08,805 | client.py:397 | Client 6: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 6: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:52:08,814 | client.py:397 | Client 9: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 9: stage 2 completes. uploading masked weights...
# DEBUG flwr 2025-02-21 18:52:08,820 | server_returns_parameters.py:237 | fit_round 3 received 5 results and 5 failures
# DEBUG:flwr:fit_round 3 received 5 results and 5 failures
# INFO flwr 2025-02-21 18:52:08,821 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:08,823 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:08,824 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:08,826 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:08,827 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:08,828 | strategy.py:186 | Length of content is 4
# INFO:flwr:Length of content is 4
# INFO flwr 2025-02-21 18:52:08,832 | server_returns_parameters.py:171 | evaluate_round 3: no clients selected, cancel
# INFO:flwr:evaluate_round 3: no clients selected, cancel
# INFO flwr 2025-02-21 18:52:08,833 | strategy.py:120 | Configure fit: stage 3, 0, False
# INFO:flwr:Configure fit: stage 3, 0, False
# DEBUG flwr 2025-02-21 18:52:08,835 | server_returns_parameters.py:223 | fit_round 4: strategy sampled 5 clients (out of 3290)
# DEBUG:flwr:fit_round 4: strategy sampled 5 clients (out of 3290)
# INFO flwr 2025-02-21 18:52:08,841 | client.py:146 | CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO:flwr:CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO flwr 2025-02-21 18:52:08,847 | client.py:146 | CID 678 reloading from /content/secagg/client_data/678.pth
# INFO:flwr:CID 678 reloading from /content/secagg/client_data/678.pth
# INFO flwr 2025-02-21 18:52:08,849 | client.py:146 | CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO:flwr:CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO flwr 2025-02-21 18:52:08,855 | client.py:146 | CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO:flwr:CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO flwr 2025-02-21 18:52:08,859 | client.py:146 | CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO:flwr:CID 2997 reloading from /content/secagg/client_data/2997.pth
# DEBUG flwr 2025-02-21 18:52:08,882 | server_returns_parameters.py:237 | fit_round 4 received 5 results and 0 failures
# DEBUG:flwr:fit_round 4 received 5 results and 0 failures
# INFO flwr 2025-02-21 18:52:08,884 | strategy.py:186 | Length of content is 2886
# INFO:flwr:Length of content is 2886
# INFO flwr 2025-02-21 18:52:09,377 | server_returns_parameters.py:171 | evaluate_round 4: no clients selected, cancel
# INFO:flwr:evaluate_round 4: no clients selected, cancel
# INFO flwr 2025-02-21 18:52:09,381 | strategy.py:120 | Configure fit: stage 0, 0, True
# INFO:flwr:Configure fit: stage 0, 0, True
# INFO flwr 2025-02-21 18:52:09,383 | strategy.py:126 | Stage 0
# INFO:flwr:Stage 0
# DEBUG flwr 2025-02-21 18:52:09,386 | server_returns_parameters.py:223 | fit_round 5: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 5: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-21 18:52:09,387 | client.py:181 | Client 0: starting stage 0...
# INFO:flwr:Client 0: starting stage 0...
# INFO flwr 2025-02-21 18:52:09,390 | client.py:181 | Client 1: starting stage 0...
# INFO:flwr:Client 1: starting stage 0...
# INFO flwr 2025-02-21 18:52:09,398 | client.py:181 | Client 2: starting stage 0...
# INFO:flwr:Client 2: starting stage 0...
# INFO flwr 2025-02-21 18:52:09,399 | client.py:181 | Client 3: starting stage 0...
# INFO:flwr:Client 3: starting stage 0...
# INFO flwr 2025-02-21 18:52:09,406 | client.py:209 | Client 0: stage 0 completes. uploading public keys...
# INFO:flwr:Client 0: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:09,427 | client.py:181 | Client 6: starting stage 0...
# INFO:flwr:Client 6: starting stage 0...
# INFO flwr 2025-02-21 18:52:09,432 | client.py:209 | Client 6: stage 0 completes. uploading public keys...
# INFO:flwr:Client 6: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:09,428 | client.py:181 | Client 4: starting stage 0...
# INFO flwr 2025-02-21 18:52:09,428 | client.py:209 | Client 3: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:09,429 | client.py:209 | Client 1: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:09,412 | client.py:181 | Client 5: starting stage 0...
# INFO flwr 2025-02-21 18:52:09,414 | client.py:209 | Client 2: stage 0 completes. uploading public keys...
# INFO:flwr:Client 4: starting stage 0...
# INFO:flwr:Client 3: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:09,452 | client.py:181 | Client 7: starting stage 0...
# INFO:flwr:Client 1: stage 0 completes. uploading public keys...
# INFO:flwr:Client 5: starting stage 0...
# INFO:flwr:Client 2: stage 0 completes. uploading public keys...
# INFO:flwr:Client 7: starting stage 0...
# INFO flwr 2025-02-21 18:52:09,454 | client.py:181 | Client 8: starting stage 0...
# INFO:flwr:Client 8: starting stage 0...
# INFO flwr 2025-02-21 18:52:09,462 | client.py:209 | Client 5: stage 0 completes. uploading public keys...
# INFO:flwr:Client 5: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:09,471 | client.py:181 | Client 9: starting stage 0...
# INFO flwr 2025-02-21 18:52:09,471 | client.py:209 | Client 4: stage 0 completes. uploading public keys...
# INFO:flwr:Client 9: starting stage 0...
# INFO:flwr:Client 4: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:09,491 | client.py:209 | Client 8: stage 0 completes. uploading public keys...
# INFO:flwr:Client 8: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:09,497 | client.py:209 | Client 9: stage 0 completes. uploading public keys...
# INFO:flwr:Client 9: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:09,498 | client.py:209 | Client 7: stage 0 completes. uploading public keys...
# INFO:flwr:Client 7: stage 0 completes. uploading public keys...
# DEBUG flwr 2025-02-21 18:52:09,517 | server_returns_parameters.py:237 | fit_round 5 received 10 results and 0 failures
# DEBUG:flwr:fit_round 5 received 10 results and 0 failures
# INFO flwr 2025-02-21 18:52:09,521 | strategy.py:186 | Length of content is 450
# INFO:flwr:Length of content is 450
# INFO flwr 2025-02-21 18:52:09,522 | server_returns_parameters.py:171 | evaluate_round 5: no clients selected, cancel
# INFO:flwr:evaluate_round 5: no clients selected, cancel
# INFO flwr 2025-02-21 18:52:09,523 | strategy.py:120 | Configure fit: stage 1, 0, False
# INFO:flwr:Configure fit: stage 1, 0, False
# DEBUG flwr 2025-02-21 18:52:09,524 | server_returns_parameters.py:223 | fit_round 6: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 6: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-21 18:52:09,527 | client.py:146 | CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO:flwr:CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO flwr 2025-02-21 18:52:09,531 | client.py:146 | CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO:flwr:CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO flwr 2025-02-21 18:52:09,531 | client.py:146 | CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO flwr 2025-02-21 18:52:09,532 | client.py:146 | CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO:flwr:CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO:flwr:CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO flwr 2025-02-21 18:52:09,546 | client.py:221 | Client 9: starting stage 1...
# INFO:flwr:Client 9: starting stage 1...
# INFO flwr 2025-02-21 18:52:09,540 | client.py:221 | Client 8: starting stage 1...
# INFO flwr 2025-02-21 18:52:09,544 | client.py:221 | Client 4: starting stage 1...
# INFO:flwr:Client 8: starting stage 1...
# INFO flwr 2025-02-21 18:52:09,538 | client.py:221 | Client 5: starting stage 1...
# INFO:flwr:Client 4: starting stage 1...
# INFO:flwr:Client 5: starting stage 1...
# INFO flwr 2025-02-21 18:52:09,551 | client.py:146 | CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO:flwr:CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO flwr 2025-02-21 18:52:09,553 | client.py:146 | CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO:flwr:CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO flwr 2025-02-21 18:52:09,561 | client.py:221 | Client 3: starting stage 1...
# INFO:flwr:Client 3: starting stage 1...
# INFO flwr 2025-02-21 18:52:09,564 | client.py:221 | Client 2: starting stage 1...
# INFO:flwr:Client 2: starting stage 1...
# INFO flwr 2025-02-21 18:52:09,683 | client.py:287 | Client 9: stage 1 completes. uploading key shares...
# INFO:flwr:Client 9: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:09,701 | client.py:146 | CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO:flwr:CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO flwr 2025-02-21 18:52:09,718 | client.py:221 | Client 1: starting stage 1...
# INFO:flwr:Client 1: starting stage 1...
# INFO flwr 2025-02-21 18:52:09,778 | client.py:287 | Client 4: stage 1 completes. uploading key shares...
# INFO:flwr:Client 4: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:09,802 | client.py:146 | CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO:flwr:CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO flwr 2025-02-21 18:52:09,816 | client.py:221 | Client 0: starting stage 1...
# INFO:flwr:Client 0: starting stage 1...
# INFO flwr 2025-02-21 18:52:09,844 | client.py:287 | Client 8: stage 1 completes. uploading key shares...
# INFO:flwr:Client 8: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:09,851 | client.py:146 | CID 839 reloading from /content/secagg/client_data/839.pth
# INFO:flwr:CID 839 reloading from /content/secagg/client_data/839.pth
# INFO flwr 2025-02-21 18:52:09,869 | client.py:221 | Client 7: starting stage 1...
# INFO:flwr:Client 7: starting stage 1...
# INFO flwr 2025-02-21 18:52:09,884 | client.py:287 | Client 3: stage 1 completes. uploading key shares...
# INFO:flwr:Client 3: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:09,898 | client.py:146 | CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO:flwr:CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO flwr 2025-02-21 18:52:09,920 | client.py:221 | Client 6: starting stage 1...
# INFO:flwr:Client 6: starting stage 1...
# INFO flwr 2025-02-21 18:52:09,933 | client.py:287 | Client 2: stage 1 completes. uploading key shares...
# INFO:flwr:Client 2: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:09,972 | client.py:287 | Client 5: stage 1 completes. uploading key shares...
# INFO:flwr:Client 5: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:10,023 | client.py:287 | Client 7: stage 1 completes. uploading key shares...
# INFO:flwr:Client 7: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:10,097 | client.py:287 | Client 1: stage 1 completes. uploading key shares...
# INFO:flwr:Client 1: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:10,100 | client.py:287 | Client 6: stage 1 completes. uploading key shares...
# INFO:flwr:Client 6: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:10,118 | client.py:287 | Client 0: stage 1 completes. uploading key shares...
# INFO:flwr:Client 0: stage 1 completes. uploading key shares...
# DEBUG flwr 2025-02-21 18:52:10,127 | server_returns_parameters.py:237 | fit_round 6 received 10 results and 0 failures
# DEBUG:flwr:fit_round 6 received 10 results and 0 failures
# INFO flwr 2025-02-21 18:52:10,130 | strategy.py:186 | Length of content is 7916
# INFO:flwr:Length of content is 7916
# INFO flwr 2025-02-21 18:52:10,133 | server_returns_parameters.py:171 | evaluate_round 6: no clients selected, cancel
# INFO:flwr:evaluate_round 6: no clients selected, cancel
# INFO flwr 2025-02-21 18:52:10,133 | strategy.py:120 | Configure fit: stage 2, 0, False
# INFO:flwr:Configure fit: stage 2, 0, False
# DEBUG flwr 2025-02-21 18:52:10,134 | server_returns_parameters.py:223 | fit_round 7: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 7: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-21 18:52:10,137 | client.py:146 | CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO:flwr:CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO flwr 2025-02-21 18:52:10,144 | client.py:146 | CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO:flwr:CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO flwr 2025-02-21 18:52:10,145 | client.py:295 | Client 9: starting stage 2...
# INFO:flwr:Client 9: starting stage 2...
# INFO flwr 2025-02-21 18:52:10,144 | client.py:146 | CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO:flwr:CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO flwr 2025-02-21 18:52:10,153 | client.py:295 | Client 1: starting stage 2...
# INFO:flwr:Client 1: starting stage 2...
# INFO flwr 2025-02-21 18:52:10,150 | client.py:295 | Client 2: starting stage 2...
# INFO flwr 2025-02-21 18:52:10,150 | client.py:146 | CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO:flwr:Client 2: starting stage 2...
# INFO:flwr:CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO flwr 2025-02-21 18:52:10,150 | client.py:146 | CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO flwr 2025-02-21 18:52:10,147 | client.py:146 | CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO:flwr:CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO:flwr:CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO flwr 2025-02-21 18:52:10,172 | client.py:146 | CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO flwr 2025-02-21 18:52:10,175 | client.py:295 | Client 5: starting stage 2...
# INFO:flwr:CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO:flwr:Client 5: starting stage 2...
# INFO flwr 2025-02-21 18:52:10,179 | client.py:146 | CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO:flwr:CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO flwr 2025-02-21 18:52:10,181 | client.py:295 | Client 6: starting stage 2...
# INFO:flwr:Client 6: starting stage 2...
# INFO flwr 2025-02-21 18:52:10,184 | client.py:295 | Client 4: starting stage 2...
# INFO:flwr:Client 4: starting stage 2...
# INFO flwr 2025-02-21 18:52:10,193 | client.py:295 | Client 3: starting stage 2...
# INFO:flwr:Client 3: starting stage 2...
# INFO flwr 2025-02-21 18:52:10,214 | client.py:146 | CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO:flwr:CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO flwr 2025-02-21 18:52:10,212 | client.py:146 | CID 839 reloading from /content/secagg/client_data/839.pth
# INFO:flwr:CID 839 reloading from /content/secagg/client_data/839.pth
# INFO flwr 2025-02-21 18:52:10,196 | client.py:295 | Client 0: starting stage 2...
# INFO:flwr:Client 0: starting stage 2...
# INFO flwr 2025-02-21 18:52:10,218 | client.py:295 | Client 8: starting stage 2...
# INFO:flwr:Client 8: starting stage 2...
# INFO flwr 2025-02-21 18:52:10,222 | client.py:295 | Client 7: starting stage 2...
# INFO flwr 2025-02-21 18:52:10,227 | client.py:397 | Client 9: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 7: starting stage 2...
# INFO:flwr:Client 9: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:52:10,295 | client.py:397 | Client 6: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 6: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:52:10,296 | client.py:397 | Client 5: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 5: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:52:10,319 | client.py:397 | Client 8: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 8: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:52:10,332 | client.py:397 | Client 7: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 7: stage 2 completes. uploading masked weights...
# DEBUG flwr 2025-02-21 18:52:10,341 | server_returns_parameters.py:237 | fit_round 7 received 5 results and 5 failures
# DEBUG:flwr:fit_round 7 received 5 results and 5 failures
# INFO flwr 2025-02-21 18:52:10,347 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:10,348 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:10,349 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:10,350 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:10,350 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:10,351 | strategy.py:186 | Length of content is 4
# INFO:flwr:Length of content is 4
# INFO flwr 2025-02-21 18:52:10,353 | server_returns_parameters.py:171 | evaluate_round 7: no clients selected, cancel
# INFO:flwr:evaluate_round 7: no clients selected, cancel
# INFO flwr 2025-02-21 18:52:10,356 | strategy.py:120 | Configure fit: stage 3, 0, False
# INFO:flwr:Configure fit: stage 3, 0, False
# DEBUG flwr 2025-02-21 18:52:10,357 | server_returns_parameters.py:223 | fit_round 8: strategy sampled 5 clients (out of 3290)
# DEBUG:flwr:fit_round 8: strategy sampled 5 clients (out of 3290)
# INFO flwr 2025-02-21 18:52:10,360 | client.py:146 | CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO:flwr:CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO flwr 2025-02-21 18:52:10,364 | client.py:146 | CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO flwr 2025-02-21 18:52:10,365 | client.py:146 | CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO flwr 2025-02-21 18:52:10,367 | client.py:146 | CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO:flwr:CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO:flwr:CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO:flwr:CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO flwr 2025-02-21 18:52:10,401 | client.py:146 | CID 839 reloading from /content/secagg/client_data/839.pth
# INFO:flwr:CID 839 reloading from /content/secagg/client_data/839.pth
# DEBUG flwr 2025-02-21 18:52:10,410 | server_returns_parameters.py:237 | fit_round 8 received 5 results and 0 failures
# DEBUG:flwr:fit_round 8 received 5 results and 0 failures
# INFO flwr 2025-02-21 18:52:10,413 | strategy.py:186 | Length of content is 2886
# INFO:flwr:Length of content is 2886
# INFO flwr 2025-02-21 18:52:10,837 | server_returns_parameters.py:171 | evaluate_round 8: no clients selected, cancel
# INFO:flwr:evaluate_round 8: no clients selected, cancel
# INFO flwr 2025-02-21 18:52:10,840 | server_returns_parameters.py:150 | FL finished in 2.658279923000009
# INFO:flwr:FL finished in 2.658279923000009
# INFO flwr 2025-02-21 18:52:10,841 | app.py:250 | app_fit: losses_distributed []
# INFO:flwr:app_fit: losses_distributed []
# INFO flwr 2025-02-21 18:52:10,844 | app.py:251 | app_fit: metrics_distributed_fit {'total_cost': [(1, 4500), (2, 79160), (3, 42300), (4, 14430), (5, 4500), (6, 79160), (7, 42300), (8, 14430)]}
# INFO:flwr:app_fit: metrics_distributed_fit {'total_cost': [(1, 4500), (2, 79160), (3, 42300), (4, 14430), (5, 4500), (6, 79160), (7, 42300), (8, 14430)]}
# INFO flwr 2025-02-21 18:52:10,846 | app.py:252 | app_fit: metrics_distributed {}
# INFO:flwr:app_fit: metrics_distributed {}
# INFO flwr 2025-02-21 18:52:10,846 | app.py:253 | app_fit: losses_centralized []
# INFO:flwr:app_fit: losses_centralized []
# INFO flwr 2025-02-21 18:52:10,847 | app.py:254 | app_fit: metrics_centralized {}
# INFO:flwr:app_fit: metrics_centralized {}
# INFO flwr 2025-02-21 18:52:10,909 | app.py:149 | Starting Flower simulation, config: ServerConfig(num_rounds=8, round_timeout=None)
# INFO:flwr:Starting Flower simulation, config: ServerConfig(num_rounds=8, round_timeout=None)
# INFO flwr 2025-02-21 18:52:10,919 | server_returns_parameters.py:81 | Initializing global parameters
# INFO:flwr:Initializing global parameters
# INFO flwr 2025-02-21 18:52:10,923 | server_returns_parameters.py:273 | Using initial parameters provided by strategy
# INFO:flwr:Using initial parameters provided by strategy
# INFO flwr 2025-02-21 18:52:10,929 | server_returns_parameters.py:84 | Evaluating initial parameters
# INFO:flwr:Evaluating initial parameters
# INFO flwr 2025-02-21 18:52:10,933 | server_returns_parameters.py:97 | FL starting
# INFO:flwr:FL starting
# INFO flwr 2025-02-21 18:52:10,935 | strategy.py:120 | Configure fit: stage 0, 0, True
# INFO:flwr:Configure fit: stage 0, 0, True
# INFO flwr 2025-02-21 18:52:10,940 | strategy.py:126 | Stage 0
# INFO:flwr:Stage 0
# DEBUG flwr 2025-02-21 18:52:10,942 | server_returns_parameters.py:223 | fit_round 1: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 1: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-21 18:52:10,948 | client.py:181 | Client 2: starting stage 0...
# INFO:flwr:Client 2: starting stage 0...
# INFO flwr 2025-02-21 18:52:10,949 | client.py:181 | Client 3: starting stage 0...
# INFO:flwr:Client 3: starting stage 0...
# INFO flwr 2025-02-21 18:52:10,951 | client.py:181 | Client 1: starting stage 0...
# INFO flwr 2025-02-21 18:52:10,951 | client.py:181 | Client 0: starting stage 0...
# INFO:flwr:Client 1: starting stage 0...
# INFO:flwr:Client 0: starting stage 0...
# INFO flwr 2025-02-21 18:52:10,952 | client.py:181 | Client 4: starting stage 0...
# INFO:flwr:Client 4: starting stage 0...
# INFO flwr 2025-02-21 18:52:10,960 | client.py:209 | Client 2: stage 0 completes. uploading public keys...
# INFO:flwr:Client 2: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:10,961 | client.py:181 | Client 5: starting stage 0...
# INFO:flwr:Client 5: starting stage 0...
# INFO flwr 2025-02-21 18:52:10,966 | client.py:209 | Client 1: stage 0 completes. uploading public keys...
# INFO:flwr:Client 1: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:10,968 | client.py:209 | Client 3: stage 0 completes. uploading public keys...
# INFO:flwr:Client 3: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:10,969 | client.py:209 | Client 0: stage 0 completes. uploading public keys...
# INFO:flwr:Client 0: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:10,980 | client.py:181 | Client 6: starting stage 0...
# INFO:flwr:Client 6: starting stage 0...
# INFO flwr 2025-02-21 18:52:10,981 | client.py:209 | Client 4: stage 0 completes. uploading public keys...
# INFO:flwr:Client 4: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:10,981 | client.py:209 | Client 5: stage 0 completes. uploading public keys...
# INFO:flwr:Client 5: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:10,988 | client.py:181 | Client 7: starting stage 0...
# INFO:flwr:Client 7: starting stage 0...
# INFO flwr 2025-02-21 18:52:10,990 | client.py:181 | Client 8: starting stage 0...
# INFO:flwr:Client 8: starting stage 0...
# INFO flwr 2025-02-21 18:52:10,991 | client.py:181 | Client 9: starting stage 0...
# INFO:flwr:Client 9: starting stage 0...
# INFO flwr 2025-02-21 18:52:10,995 | client.py:209 | Client 6: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:11,003 | client.py:209 | Client 7: stage 0 completes. uploading public keys...
# INFO:flwr:Client 6: stage 0 completes. uploading public keys...
# INFO:flwr:Client 7: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:11,007 | client.py:209 | Client 8: stage 0 completes. uploading public keys...
# INFO:flwr:Client 8: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:11,019 | client.py:209 | Client 9: stage 0 completes. uploading public keys...
# INFO:flwr:Client 9: stage 0 completes. uploading public keys...
# DEBUG flwr 2025-02-21 18:52:11,035 | server_returns_parameters.py:237 | fit_round 1 received 10 results and 0 failures
# DEBUG:flwr:fit_round 1 received 10 results and 0 failures
# INFO flwr 2025-02-21 18:52:11,037 | strategy.py:186 | Length of content is 450
# INFO:flwr:Length of content is 450
# INFO flwr 2025-02-21 18:52:11,038 | server_returns_parameters.py:171 | evaluate_round 1: no clients selected, cancel
# INFO:flwr:evaluate_round 1: no clients selected, cancel
# INFO flwr 2025-02-21 18:52:11,040 | strategy.py:120 | Configure fit: stage 1, 0, False
# INFO:flwr:Configure fit: stage 1, 0, False
# DEBUG flwr 2025-02-21 18:52:11,042 | server_returns_parameters.py:223 | fit_round 2: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 2: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-21 18:52:11,046 | client.py:146 | CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO:flwr:CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO flwr 2025-02-21 18:52:11,047 | client.py:146 | CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO flwr 2025-02-21 18:52:11,049 | client.py:146 | CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO:flwr:CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO flwr 2025-02-21 18:52:11,050 | client.py:146 | CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO:flwr:CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO flwr 2025-02-21 18:52:11,050 | client.py:146 | CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO flwr 2025-02-21 18:52:11,055 | client.py:221 | Client 6: starting stage 1...
# INFO:flwr:CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO flwr 2025-02-21 18:52:11,052 | client.py:146 | CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO:flwr:CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO flwr 2025-02-21 18:52:11,057 | client.py:221 | Client 5: starting stage 1...
# INFO flwr 2025-02-21 18:52:11,062 | client.py:221 | Client 4: starting stage 1...
# INFO:flwr:Client 6: starting stage 1...
# INFO:flwr:Client 4: starting stage 1...
# INFO flwr 2025-02-21 18:52:11,062 | client.py:221 | Client 8: starting stage 1...
# INFO:flwr:Client 5: starting stage 1...
# INFO:flwr:CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO:flwr:Client 8: starting stage 1...
# INFO flwr 2025-02-21 18:52:11,070 | client.py:221 | Client 0: starting stage 1...
# INFO:flwr:Client 0: starting stage 1...
# INFO flwr 2025-02-21 18:52:11,077 | client.py:221 | Client 9: starting stage 1...
# INFO:flwr:Client 9: starting stage 1...
# INFO flwr 2025-02-21 18:52:11,172 | client.py:287 | Client 5: stage 1 completes. uploading key shares...
# INFO:flwr:Client 5: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:11,193 | client.py:146 | CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO:flwr:CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO flwr 2025-02-21 18:52:11,204 | client.py:221 | Client 3: starting stage 1...
# INFO:flwr:Client 3: starting stage 1...
# INFO flwr 2025-02-21 18:52:11,227 | client.py:287 | Client 0: stage 1 completes. uploading key shares...
# INFO:flwr:Client 0: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:11,240 | client.py:146 | CID 678 reloading from /content/secagg/client_data/678.pth
# INFO:flwr:CID 678 reloading from /content/secagg/client_data/678.pth
# INFO flwr 2025-02-21 18:52:11,271 | client.py:287 | Client 8: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:11,279 | client.py:221 | Client 7: starting stage 1...
# INFO:flwr:Client 8: stage 1 completes. uploading key shares...
# INFO:flwr:Client 7: starting stage 1...
# INFO flwr 2025-02-21 18:52:11,312 | client.py:146 | CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO:flwr:CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO flwr 2025-02-21 18:52:11,328 | client.py:221 | Client 2: starting stage 1...
# INFO:flwr:Client 2: starting stage 1...
# INFO flwr 2025-02-21 18:52:11,332 | client.py:287 | Client 6: stage 1 completes. uploading key shares...
# INFO:flwr:Client 6: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:11,337 | client.py:287 | Client 4: stage 1 completes. uploading key shares...
# INFO:flwr:Client 4: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:11,354 | client.py:146 | CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO:flwr:CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO flwr 2025-02-21 18:52:11,366 | client.py:221 | Client 1: starting stage 1...
# INFO:flwr:Client 1: starting stage 1...
# INFO flwr 2025-02-21 18:52:11,388 | client.py:287 | Client 9: stage 1 completes. uploading key shares...
# INFO:flwr:Client 9: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:11,414 | client.py:287 | Client 3: stage 1 completes. uploading key shares...
# INFO:flwr:Client 3: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:11,475 | client.py:287 | Client 7: stage 1 completes. uploading key shares...
# INFO:flwr:Client 7: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:11,495 | client.py:287 | Client 1: stage 1 completes. uploading key shares...
# INFO:flwr:Client 1: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:11,506 | client.py:287 | Client 2: stage 1 completes. uploading key shares...
# INFO:flwr:Client 2: stage 1 completes. uploading key shares...
# DEBUG flwr 2025-02-21 18:52:11,514 | server_returns_parameters.py:237 | fit_round 2 received 10 results and 0 failures
# DEBUG:flwr:fit_round 2 received 10 results and 0 failures
# INFO flwr 2025-02-21 18:52:11,517 | strategy.py:186 | Length of content is 7916
# INFO:flwr:Length of content is 7916
# INFO flwr 2025-02-21 18:52:11,521 | server_returns_parameters.py:171 | evaluate_round 2: no clients selected, cancel
# INFO:flwr:evaluate_round 2: no clients selected, cancel
# INFO flwr 2025-02-21 18:52:11,522 | strategy.py:120 | Configure fit: stage 2, 0, False
# INFO:flwr:Configure fit: stage 2, 0, False
# DEBUG flwr 2025-02-21 18:52:11,525 | server_returns_parameters.py:223 | fit_round 3: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 3: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-21 18:52:11,528 | client.py:146 | CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO:flwr:CID 2338 reloading from /content/secagg/client_data/2338.pth
# INFO flwr 2025-02-21 18:52:11,531 | client.py:295 | Client 4: starting stage 2...
# INFO:flwr:Client 4: starting stage 2...
# INFO flwr 2025-02-21 18:52:11,534 | client.py:146 | CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO:flwr:CID 2184 reloading from /content/secagg/client_data/2184.pth
# INFO flwr 2025-02-21 18:52:11,534 | client.py:146 | CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO:flwr:CID 1498 reloading from /content/secagg/client_data/1498.pth
# INFO flwr 2025-02-21 18:52:11,541 | client.py:295 | Client 3: starting stage 2...
# INFO:flwr:Client 3: starting stage 2...
# INFO flwr 2025-02-21 18:52:11,545 | client.py:146 | CID 678 reloading from /content/secagg/client_data/678.pth
# INFO:flwr:CID 678 reloading from /content/secagg/client_data/678.pth
# INFO flwr 2025-02-21 18:52:11,545 | client.py:295 | Client 1: starting stage 2...
# INFO flwr 2025-02-21 18:52:11,546 | client.py:146 | CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO flwr 2025-02-21 18:52:11,550 | client.py:146 | CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO flwr 2025-02-21 18:52:11,551 | client.py:146 | CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO:flwr:Client 1: starting stage 2...
# INFO flwr 2025-02-21 18:52:11,554 | client.py:295 | Client 7: starting stage 2...
# INFO:flwr:CID 3175 reloading from /content/secagg/client_data/3175.pth
# INFO:flwr:CID 1363 reloading from /content/secagg/client_data/1363.pth
# INFO flwr 2025-02-21 18:52:11,556 | client.py:146 | CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO:flwr:CID 2399 reloading from /content/secagg/client_data/2399.pth
# INFO flwr 2025-02-21 18:52:11,559 | client.py:146 | CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO flwr 2025-02-21 18:52:11,562 | client.py:295 | Client 8: starting stage 2...
# INFO flwr 2025-02-21 18:52:11,563 | client.py:295 | Client 9: starting stage 2...
# INFO:flwr:Client 7: starting stage 2...
# INFO:flwr:CID 2530 reloading from /content/secagg/client_data/2530.pth
# INFO flwr 2025-02-21 18:52:11,569 | client.py:295 | Client 5: starting stage 2...
# INFO:flwr:CID 2907 reloading from /content/secagg/client_data/2907.pth
# INFO flwr 2025-02-21 18:52:11,574 | client.py:295 | Client 0: starting stage 2...
# INFO:flwr:Client 8: starting stage 2...
# INFO flwr 2025-02-21 18:52:11,580 | client.py:295 | Client 2: starting stage 2...
# INFO:flwr:Client 9: starting stage 2...
# INFO:flwr:Client 5: starting stage 2...
# INFO:flwr:Client 0: starting stage 2...
# INFO:flwr:Client 2: starting stage 2...
# INFO flwr 2025-02-21 18:52:11,623 | client.py:146 | CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO:flwr:CID 2997 reloading from /content/secagg/client_data/2997.pth
# INFO flwr 2025-02-21 18:52:11,641 | client.py:295 | Client 6: starting stage 2...
# INFO:flwr:Client 6: starting stage 2...
# ...
# INFO flwr 2025-02-21 18:52:23,724 | client.py:209 | Client 4: stage 0 completes. uploading public keys...
# INFO:flwr:Client 0: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:23,729 | client.py:209 | Client 2: stage 0 completes. uploading public keys...
# INFO:flwr:Client 1: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:23,731 | client.py:209 | Client 3: stage 0 completes. uploading public keys...
# INFO:flwr:Client 4: stage 0 completes. uploading public keys...
# INFO:flwr:Client 2: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:23,732 | client.py:209 | Client 5: stage 0 completes. uploading public keys...
# INFO:flwr:Client 3: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:23,740 | client.py:181 | Client 6: starting stage 0...
# INFO:flwr:Client 6: starting stage 0...
# INFO flwr 2025-02-21 18:52:23,745 | client.py:181 | Client 7: starting stage 0...
# INFO flwr 2025-02-21 18:52:23,746 | client.py:181 | Client 8: starting stage 0...
# INFO:flwr:Client 5: stage 0 completes. uploading public keys...
# INFO:flwr:Client 7: starting stage 0...
# INFO flwr 2025-02-21 18:52:23,751 | client.py:181 | Client 9: starting stage 0...
# INFO:flwr:Client 8: starting stage 0...
# INFO flwr 2025-02-21 18:52:23,766 | client.py:209 | Client 7: stage 0 completes. uploading public keys...
# INFO:flwr:Client 9: starting stage 0...
# INFO flwr 2025-02-21 18:52:23,759 | client.py:209 | Client 6: stage 0 completes. uploading public keys...
# INFO:flwr:Client 7: stage 0 completes. uploading public keys...
# INFO:flwr:Client 6: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:23,771 | client.py:209 | Client 8: stage 0 completes. uploading public keys...
# INFO:flwr:Client 8: stage 0 completes. uploading public keys...
# INFO flwr 2025-02-21 18:52:23,775 | client.py:209 | Client 9: stage 0 completes. uploading public keys...
# INFO:flwr:Client 9: stage 0 completes. uploading public keys...
# DEBUG flwr 2025-02-21 18:52:23,791 | server_returns_parameters.py:237 | fit_round 5 received 10 results and 0 failures
# DEBUG:flwr:fit_round 5 received 10 results and 0 failures
# INFO flwr 2025-02-21 18:52:23,792 | strategy.py:186 | Length of content is 450
# INFO:flwr:Length of content is 450
# INFO flwr 2025-02-21 18:52:23,793 | server_returns_parameters.py:171 | evaluate_round 5: no clients selected, cancel
# INFO:flwr:evaluate_round 5: no clients selected, cancel
# INFO flwr 2025-02-21 18:52:23,794 | strategy.py:120 | Configure fit: stage 1, 0, False
# INFO:flwr:Configure fit: stage 1, 0, False
# DEBUG flwr 2025-02-21 18:52:23,795 | server_returns_parameters.py:223 | fit_round 6: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 6: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-21 18:52:23,797 | client.py:146 | CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO:flwr:CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO flwr 2025-02-21 18:52:23,800 | client.py:221 | Client 2: starting stage 1...
# INFO:flwr:Client 2: starting stage 1...
# INFO flwr 2025-02-21 18:52:23,801 | client.py:146 | CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO:flwr:CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO flwr 2025-02-21 18:52:23,804 | client.py:221 | Client 3: starting stage 1...
# INFO:flwr:Client 3: starting stage 1...
# INFO flwr 2025-02-21 18:52:23,805 | client.py:146 | CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO:flwr:CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO flwr 2025-02-21 18:52:23,807 | client.py:221 | Client 5: starting stage 1...
# INFO:flwr:Client 5: starting stage 1...
# INFO flwr 2025-02-21 18:52:23,809 | client.py:146 | CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO:flwr:CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO flwr 2025-02-21 18:52:23,811 | client.py:221 | Client 8: starting stage 1...
# INFO:flwr:Client 8: starting stage 1...
# INFO flwr 2025-02-21 18:52:23,813 | client.py:146 | CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO:flwr:CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO flwr 2025-02-21 18:52:23,823 | client.py:221 | Client 0: starting stage 1...
# INFO:flwr:Client 0: starting stage 1...
# INFO flwr 2025-02-21 18:52:23,825 | client.py:146 | CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO:flwr:CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO flwr 2025-02-21 18:52:23,828 | client.py:221 | Client 9: starting stage 1...
# INFO:flwr:Client 9: starting stage 1...
# INFO flwr 2025-02-21 18:52:23,896 | client.py:287 | Client 3: stage 1 completes. uploading key shares...
# INFO:flwr:Client 3: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:23,907 | client.py:146 | CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO:flwr:CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO flwr 2025-02-21 18:52:23,917 | client.py:221 | Client 4: starting stage 1...
# INFO:flwr:Client 4: starting stage 1...
# INFO flwr 2025-02-21 18:52:23,946 | client.py:287 | Client 2: stage 1 completes. uploading key shares...
# INFO:flwr:Client 2: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:23,959 | client.py:146 | CID 839 reloading from /content/secagg/client_data/839.pth
# INFO:flwr:CID 839 reloading from /content/secagg/client_data/839.pth
# INFO flwr 2025-02-21 18:52:23,966 | client.py:221 | Client 7: starting stage 1...
# INFO:flwr:Client 7: starting stage 1...
# INFO flwr 2025-02-21 18:52:23,987 | client.py:287 | Client 5: stage 1 completes. uploading key shares...
# INFO:flwr:Client 5: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:24,001 | client.py:146 | CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO:flwr:CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO flwr 2025-02-21 18:52:24,009 | client.py:221 | Client 6: starting stage 1...
# INFO:flwr:Client 6: starting stage 1...
# INFO flwr 2025-02-21 18:52:24,030 | client.py:287 | Client 9: stage 1 completes. uploading key shares...
# INFO:flwr:Client 9: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:24,047 | client.py:146 | CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO:flwr:CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO flwr 2025-02-21 18:52:24,077 | client.py:221 | Client 1: starting stage 1...
# INFO:flwr:Client 1: starting stage 1...
# INFO flwr 2025-02-21 18:52:24,124 | client.py:287 | Client 4: stage 1 completes. uploading key shares...
# INFO:flwr:Client 4: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:24,139 | client.py:287 | Client 8: stage 1 completes. uploading key shares...
# INFO:flwr:Client 8: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:24,213 | client.py:287 | Client 0: stage 1 completes. uploading key shares...
# INFO:flwr:Client 0: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:24,285 | client.py:287 | Client 6: stage 1 completes. uploading key shares...
# INFO:flwr:Client 6: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:24,313 | client.py:287 | Client 1: stage 1 completes. uploading key shares...
# INFO:flwr:Client 1: stage 1 completes. uploading key shares...
# INFO flwr 2025-02-21 18:52:24,326 | client.py:287 | Client 7: stage 1 completes. uploading key shares...
# INFO:flwr:Client 7: stage 1 completes. uploading key shares...
# DEBUG flwr 2025-02-21 18:52:24,333 | server_returns_parameters.py:237 | fit_round 6 received 10 results and 0 failures
# DEBUG:flwr:fit_round 6 received 10 results and 0 failures
# INFO flwr 2025-02-21 18:52:24,335 | strategy.py:186 | Length of content is 7916
# INFO:flwr:Length of content is 7916
# INFO flwr 2025-02-21 18:52:24,338 | server_returns_parameters.py:171 | evaluate_round 6: no clients selected, cancel
# INFO:flwr:evaluate_round 6: no clients selected, cancel
# INFO flwr 2025-02-21 18:52:24,339 | strategy.py:120 | Configure fit: stage 2, 0, False
# INFO:flwr:Configure fit: stage 2, 0, False
# DEBUG flwr 2025-02-21 18:52:24,341 | server_returns_parameters.py:223 | fit_round 7: strategy sampled 10 clients (out of 3290)
# DEBUG:flwr:fit_round 7: strategy sampled 10 clients (out of 3290)
# INFO flwr 2025-02-21 18:52:24,343 | client.py:146 | CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO:flwr:CID 1473 reloading from /content/secagg/client_data/1473.pth
# INFO flwr 2025-02-21 18:52:24,347 | client.py:295 | Client 3: starting stage 2...
# INFO:flwr:Client 3: starting stage 2...
# INFO flwr 2025-02-21 18:52:24,348 | client.py:146 | CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO:flwr:CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO flwr 2025-02-21 18:52:24,355 | client.py:295 | Client 9: starting stage 2...
# INFO:flwr:Client 9: starting stage 2...
# INFO flwr 2025-02-21 18:52:24,351 | client.py:146 | CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO flwr 2025-02-21 18:52:24,356 | client.py:146 | CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO:flwr:CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO:flwr:CID 1260 reloading from /content/secagg/client_data/1260.pth
# INFO flwr 2025-02-21 18:52:24,365 | client.py:146 | CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO:flwr:CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO flwr 2025-02-21 18:52:24,370 | client.py:295 | Client 6: starting stage 2...
# INFO flwr 2025-02-21 18:52:24,375 | client.py:146 | CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO:flwr:Client 6: starting stage 2...
# INFO:flwr:CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO flwr 2025-02-21 18:52:24,392 | client.py:295 | Client 4: starting stage 2...
# INFO:flwr:Client 4: starting stage 2...
# INFO flwr 2025-02-21 18:52:24,383 | client.py:295 | Client 8: starting stage 2...
# INFO:flwr:Client 8: starting stage 2...
# INFO flwr 2025-02-21 18:52:24,376 | client.py:146 | CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO:flwr:CID 3234 reloading from /content/secagg/client_data/3234.pth
# INFO flwr 2025-02-21 18:52:24,398 | client.py:295 | Client 5: starting stage 2...
# INFO:flwr:Client 5: starting stage 2...
# INFO flwr 2025-02-21 18:52:24,407 | client.py:146 | CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO:flwr:CID 1571 reloading from /content/secagg/client_data/1571.pth
# INFO flwr 2025-02-21 18:52:24,443 | client.py:295 | Client 2: starting stage 2...
# INFO:flwr:Client 2: starting stage 2...
# INFO flwr 2025-02-21 18:52:24,461 | client.py:295 | Client 0: starting stage 2...
# INFO:flwr:Client 0: starting stage 2...
# INFO flwr 2025-02-21 18:52:24,480 | client.py:146 | CID 839 reloading from /content/secagg/client_data/839.pth
# INFO:flwr:CID 839 reloading from /content/secagg/client_data/839.pth
# INFO flwr 2025-02-21 18:52:24,483 | client.py:146 | CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO flwr 2025-02-21 18:52:24,486 | client.py:295 | Client 7: starting stage 2...
# INFO:flwr:CID 2600 reloading from /content/secagg/client_data/2600.pth
# INFO:flwr:Client 7: starting stage 2...
# INFO flwr 2025-02-21 18:52:24,495 | client.py:295 | Client 1: starting stage 2...
# INFO:flwr:Client 1: starting stage 2...
# INFO flwr 2025-02-21 18:52:24,542 | client.py:397 | Client 5: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 5: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:52:24,543 | client.py:397 | Client 9: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:52:24,549 | client.py:397 | Client 8: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 9: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:52:24,551 | client.py:397 | Client 6: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 8: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 6: stage 2 completes. uploading masked weights...
# INFO flwr 2025-02-21 18:52:24,574 | client.py:397 | Client 7: stage 2 completes. uploading masked weights...
# INFO:flwr:Client 7: stage 2 completes. uploading masked weights...
# DEBUG flwr 2025-02-21 18:52:24,580 | server_returns_parameters.py:237 | fit_round 7 received 5 results and 5 failures
# DEBUG:flwr:fit_round 7 received 5 results and 5 failures
# INFO flwr 2025-02-21 18:52:24,582 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:24,583 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:24,584 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:24,585 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:24,585 | strategy.py:185 | Force dropout due to testing
# INFO:flwr:Force dropout due to testing
# INFO flwr 2025-02-21 18:52:24,586 | strategy.py:186 | Length of content is 4
# INFO:flwr:Length of content is 4
# INFO flwr 2025-02-21 18:52:24,588 | server_returns_parameters.py:171 | evaluate_round 7: no clients selected, cancel
# INFO:flwr:evaluate_round 7: no clients selected, cancel
# INFO flwr 2025-02-21 18:52:24,589 | strategy.py:120 | Configure fit: stage 3, 0, False
# INFO:flwr:Configure fit: stage 3, 0, False
# DEBUG flwr 2025-02-21 18:52:24,590 | server_returns_parameters.py:223 | fit_round 8: strategy sampled 5 clients (out of 3290)
# DEBUG:flwr:fit_round 8: strategy sampled 5 clients (out of 3290)
# INFO flwr 2025-02-21 18:52:24,594 | client.py:146 | CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO:flwr:CID 2855 reloading from /content/secagg/client_data/2855.pth
# INFO flwr 2025-02-21 18:52:24,600 | client.py:146 | CID 839 reloading from /content/secagg/client_data/839.pth
# INFO:flwr:CID 839 reloading from /content/secagg/client_data/839.pth
# INFO flwr 2025-02-21 18:52:24,600 | client.py:146 | CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO:flwr:CID 1603 reloading from /content/secagg/client_data/1603.pth
# INFO flwr 2025-02-21 18:52:24,609 | client.py:146 | CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO:flwr:CID 3119 reloading from /content/secagg/client_data/3119.pth
# INFO flwr 2025-02-21 18:52:24,619 | client.py:146 | CID 2688 reloading from /content/secagg/client_data/2688.pth
# INFO:flwr:CID 2688 reloading from /content/secagg/client_data/2688.pth
# DEBUG flwr 2025-02-21 18:52:24,625 | server_returns_parameters.py:237 | fit_round 8 received 5 results and 0 failures
# DEBUG:flwr:fit_round 8 received 5 results and 0 failures
# INFO flwr 2025-02-21 18:52:24,626 | strategy.py:186 | Length of content is 2886
# INFO:flwr:Length of content is 2886
# INFO flwr 2025-02-21 18:52:25,107 | server_returns_parameters.py:171 | evaluate_round 8: no clients selected, cancel
# INFO:flwr:evaluate_round 8: no clients selected, cancel
# INFO flwr 2025-02-21 18:52:25,108 | server_returns_parameters.py:150 | FL finished in 3.134276403000058
# INFO:flwr:FL finished in 3.134276403000058
# INFO flwr 2025-02-21 18:52:25,109 | app.py:250 | app_fit: losses_distributed []
# INFO:flwr:app_fit: losses_distributed []
# INFO flwr 2025-02-21 18:52:25,110 | app.py:251 | app_fit: metrics_distributed_fit {'total_cost': [(1, 4500), (2, 79160), (3, 1312060), (4, 14430), (5, 4500), (6, 79160), (7, 1312060), (8, 14430)]}
# INFO:flwr:app_fit: metrics_distributed_fit {'total_cost': [(1, 4500), (2, 79160), (3, 1312060), (4, 14430), (5, 4500), (6, 79160), (7, 1312060), (8, 14430)]}
# INFO flwr 2025-02-21 18:52:25,113 | app.py:252 | app_fit: metrics_distributed {}
# INFO:flwr:app_fit: metrics_distributed {}
# INFO flwr 2025-02-21 18:52:25,114 | app.py:253 | app_fit: losses_centralized []
# INFO:flwr:app_fit: losses_centralized []
# INFO flwr 2025-02-21 18:52:25,115 | app.py:254 | app_fit: metrics_centralized {}
# INFO:flwr:app_fit: metrics_centralized {}

# %%
total_cost_list = []

for num_params in num_model_parameters_list:
    total_costs = results_params[num_params][1].metrics_distributed_fit['total_cost']
    total_cost = sum(cost for _, cost in total_costs)
    total_cost_list.append(total_cost)

# %%
plt.figure(figsize=(8,6))
plt.scatter(num_model_parameters_list, total_cost_list)
plt.xlabel("Number of Model Parameters")
plt.ylabel("Total Communication Cost")
plt.title("Impact of Model Size on Communication Cost")
plt.grid(True)
plt.show()

# %% [markdown]
# The plots show an expected trade-off: increasing both model parameters and number of clients per round increase communication costs.
# This trade-off is not only specific to SA but FL itself.
#
# However, with SA the communication costs are much larger because:
# - As the number of clients per round increases, clients have to exchange more keys and messages each round.
#
# - As the number of model parameters increase, more data needs to be encrypted and exchanged every round.
#
# Therefore, with SA the privacy trade-off is between communication overhead and system complexity. If we increase model complexity or number of clients, we can train larger models and achieve a better overall model, but communication costs also increase. In some cases, such as cross-device settings, the communication costs for SA might be too high, while in others (cross-silo) they might be acceptable.

# %% [markdown]
# ---

# %% [markdown]
# **Question 10 (Part III/MPhil ✅):**
#
# (This is a purely conceptual question. Answer in **no more than 10 sentences each**.)
#
# After reading the [paper](https://arxiv.org/abs/1611.04482) and experimenting with the additional communication costs of Secure Aggregation in FL, discuss the implication of using this protocol in a real FL setting. You may want to discriminate between cross-silo and cross-device settings. You can focus on communication and computation overheads and refer to the asymptotic complexity of both.

# %% [markdown]
# ---
#
# #### **Answer to Question 10**
#
# Secure Aggregation introduces additional overheads of encryption and decryption every round, which increase both communication and computational costs.
# In cross-silo settings, where there are a lower number of clients, typically with higher computational capacity and high-bandwidth networks, these overheads are less impactful.
# In cross-device settings however, clients tend to be more resource-constrained and network connectivity can be less stable. In this case, the overheads of secure aggregation can significantly impact participation and therefore convergence.
#
# The complexity grows linearly with the model size, but quadratically with the number of clients.
#
# The computational complexity on the client side is $O(n^2 + kn)$ and on the server side is $O(kn^2)$, where $n$ is the number of clients and $k$ is the model size.
# The quadratic computational complexity in the client side comes from the pairwise exchange of secret shares between clients, whereas the server's quadratic complexity comes from the need to reconstruct secrets and aggregating results from clients.
#
# The communication complexity on the client side is $O(n + k)$ and on the server side is $O(n^2 + kn)$.
# The complexity in the client side comes from the secret shares to all the other clients ($O(n)$) and the model updates ($O(k)$).
# The server's complexity comes from the need to aggregate the results pairwise ($O(n^2)$) and process the model updates ($O(kn)$).
#
# The overall computational complexity for the clients is quadratic in the number of clients, while the communication complexity is linear.
# The overall computational and communication complexities for the server are quadratic in the number of clients.
#
# These complexities reinforce that SA scaling is more sensitive to the number of clients than model size. Therefore, it reinforces our hypothesis that, while SA may be viable in cross-silo settings, its application in cross-device settings is more challenging.
#
# In conclusion, while Secure Aggregation offers strong privacy guarantees, its real-world feasibility depends on the type and scale of system being implemented.
#
# ---

# %% [markdown]
# (c) 2024 Alexandru-Andrei Iacob, Lorenzo Sani
